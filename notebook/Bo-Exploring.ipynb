# %%
import pandas as pd


DISPLAY_ALL_TEXT = False

pd.set_option("display.max_colwidth", 0 if DISPLAY_ALL_TEXT else 50)

# %%
# !pip install rdflib
# Out:
# Requirement already satisfied: rdflib in /workspace/anaconda3/envs/bio/lib/python3.7/site-packages (5.0.0)
# Requirement already satisfied: pyparsing in /workspace/anaconda3/envs/bio/lib/python3.7/site-packages (from rdflib) (2.4.7)
# Requirement already satisfied: isodate in /workspace/anaconda3/envs/bio/lib/python3.7/site-packages (from rdflib) (0.6.0)
# Requirement already satisfied: six in /workspace/anaconda3/envs/bio/lib/python3.7/site-packages (from rdflib) (1.15.0)
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: '/workspace/anaconda3/envs/bio/lib/python3.7/site-packages/numpy-1.20.2.dist-info/METADATA'

# %%
from rdflib import Namespace
from rdflib import Graph, URIRef, Literal, RDF, ConjunctiveGraph

# %% [markdown]
# ### Dataset contains text and disease and drug mentions which were extracted from the DailyMed drug lables

# %%
unlabeled_df  = pd.read_csv('../data/input/raw_cleaned.csv.zip',  compression='zip')
unlabeled_df = unlabeled_df[['DB_ID', 'DO_ID','disease', 'Label_ID', 'DrugName', 'Context','Section' ]]
len(unlabeled_df)
# Out:
# 54040

# %%
unlabeled_df.head()
# Out:
#      DB_ID         DO_ID        disease  \
# 0  DB00752  DOID_0050773  paraganglioma
# 1  DB00752      DOID_225       syndrome
# 2  DB00752     DOID_4481      hay fever
# 3  DB00752  DOID_0050773  paraganglioma
# 4  DB00752      DOID_225       syndrome
#
#                                    Label_ID         DrugName  \
# 0  9f3ad5aa-8e9d-4512-88a5-15cfd50293f9.xml  TRANYLCYPROMINE
# 1  9f3ad5aa-8e9d-4512-88a5-15cfd50293f9.xml  TRANYLCYPROMINE
# 2  9f3ad5aa-8e9d-4512-88a5-15cfd50293f9.xml  TRANYLCYPROMINE
# 3  4de045ff-f76c-48dd-9e5f-4a4f859eec8f.xml  TRANYLCYPROMINE
# 4  4de045ff-f76c-48dd-9e5f-4a4f859eec8f.xml  TRANYLCYPROMINE
#
#                                              Context           Section
# 0  concomitant use or use in rapid succession wit...  Contraindication
# 1  concomitant use or use in rapid succession wit...  Contraindication
# 2  concomitant use or use in rapid succession wit...  Contraindication
# 3  concomitant use or use in rapid succession wit...  Contraindication
# 4  concomitant use or use in rapid succession wit...  Contraindication

# %%
unlabeled_df= unlabeled_df.rename(columns={'DrugName':'Drug_name'})
unlabeled_df.drop_duplicates(subset=['Context','DO_ID'], keep='first', inplace=True)
len(unlabeled_df)
# Out:
# 39810

# %%
unlabeled_df.columns
# Out:
# Index(['DB_ID', 'DO_ID', 'disease', 'Label_ID', 'Drug_name', 'Context',
#        'Section'],
#       dtype='object')

# %%
unlabeled_df.DB_ID= 'http://bio2rdf.org/drugbank:'+unlabeled_df.DB_ID

# %%
unlabeled_df.DO_ID= 'http://bio2rdf.org/doid:'+unlabeled_df.DO_ID.str[5:]

# %% [markdown]
# ### Dataset labelled by experts to be used as test data

# %%
experts = pd.read_csv('../data/input/expert_resolved_all.csv')
experts.sample()
# Out:
#         #                                            context  \
# 124  41.0  Bumetanide tablets USP are indicated for the t...
#
#            disease_name   drug_name  \
# 124  NEPHROTIC SYNDROME  BUMETANIDE
#
#                                        workers_answers  \
# 124  indication_treatment\nindication_symptomatic_r...
#
#                     medical_expert1 medical_expert2        medical_expert3  \
# 124  Indication: Symptomatic Relief    Inconsistent  Indication: Treatment
#
#          do_id drug_brand_name  drug_id  \
# 124  DOID_1184             NaN  DB00887
#
#                                      label_id                          sheet  \
# 124  a94471b1-a588-44e7-b17b-b99f5c3ba31d.xml  indication_symptomatic_relief
#
#                    expert_consensus  inter_agree_experts medical_expert4  \
# 124  Indication: Symptomatic Relief                    0             NaN
#
#            Final \n(closest option)
# 124  Indication: Symptomatic Relief

# %%
experts = experts.rename(columns={'drug_name':'Drug_name',
                        'disease_name':'disease', 'context':'Context',
                        'do_id':'DO_ID','drug_id':'DB_ID',
                        'label_id':'Label_ID', 'expert_consensus':'relation'})
#experts[['DB_ID', 'DO_ID','disease', 'Label_ID', 'Set_ID','relation', 'Drug_name', 'Context','Section']]

# %% [markdown]
# ### Defininig a rule as a SPARQL query
#
# If drug ?a treats disease ?f and disease ?f and ?b, then drug ?a can treat disease ?b.
# ```
# Rule : ?a CtD ?f ^ ?f DrD ?b => ?a CtD ?b
# ```
#
# ```
# SELECT DISTINCT ?a ?b where
# {
#     ?a <http://bio2rdf.org/hetionet:CtD> ?f .
#     ?f <http://bio2rdf.org/hetionet:DrD> ?b .
#     MINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .
# }
#
# ```

# %%
query='SELECT DISTINCT ?a ?b where { ?a <http://bio2rdf.org/hetionet:CtD> ?f .'
' \n ?f <http://bio2rdf.org/hetionet:DrD> ?b . '
'\nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'
# Out:
# '\nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'

# %%
query='SELECT DISTINCT ?a ?b where { ?a <http://bio2rdf.org/hetionet:CtD> ?f . \n ?f <http://bio2rdf.org/hetionet:DrD> ?b . \n    }'

# %%
g= Graph()

# %%
# !gunzip ../data/rdf/hetionet.ttl.gz

# %%
## We used Hetionet KG: https://het.io/about/ 
g.parse('../data/rdf/hetionet.ttl',format="ttl")
# Out:
# <Graph identifier=N957b3f04ce15494c8dabeba44951c731 (<class 'rdflib.graph.Graph'>)>

# %%
query='SELECT DISTINCT ?a ?b where { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b   }'

# %%
qres= g.query(query)

# %%
indications_het =set()
for row in qres:
    #print (row['a'], row['b'])
    indications_het.add((str(row['a']),str(row['b'])))
    #break
len(indications_het)
# Out:
# 755

# %%
('http://bio2rdf.org/drugbank:DB00858', 'http://bio2rdf.org/doid:1612') in indications_het
# Out:
# False

# %% [markdown]
# ### Define KG Rules as Labeling Functions in Snorkel
# Snorkel is data labeling framework where multiple heuristic and programatic rules can be combined to assign a label to training data

# %%
# Labels to be assigned 
ABSTAIN = -1
INDICATION = 1

# %%
#!pip install snorkel

# %%
from snorkel.labeling import labeling_function


@labeling_function()
def check_rule(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            print (row['a'], row['b'])
            return INDICATION
    else:
        return ABSTAIN

# %% [markdown]
# ### Define heuristics as Labeling Functions in Snorkel
# One common approach to define a rule to label text data is use of phrase, we define a list of phrases to look for in the text

# %%
treatment_phrases= [" indicated for the treatment of",
" indicated in the management of",
" indicated for the management of",
"for the management of",
"management of",
" indicated for the maintenance of remission", 
"or the treatment of",
"in the treatment of",
" indicated as",
" indicated in",
"be effective",
"active treatment of",
" indicated for",
"treatment of",
" indicated as an adjunct",
" indicated for use in the treatment of", 
" indicated for the intermittent treatment", 
" indicated to reduce the rate of",
" indicated for the rapid control",
" indicated for the control",
"reduce the risk of",
" indicated as adjunctive treatment",
"for the treatment of"]

# %%
@labeling_function()
def check_phrase(x):
    if str(x.Context) !='nan':
        text = x.Context.lower()
        #print ('text')
        for phr in treatment_phrases:
            if phr in text:
                return INDICATION
    return ABSTAIN

# %%
from snorkel.labeling import PandasLFApplier

lfs = [check_rule, check_phrase]

applier = PandasLFApplier(lfs=lfs)
L_train = applier.apply(df=unlabeled_df.sample(100))
# Out:
#  35%|███▌      | 35/100 [00:00<00:00, 174.69it/s]
# http://bio2rdf.org/drugbank:DB01234 http://bio2rdf.org/doid:3310
# http://bio2rdf.org/drugbank:DB01234 http://bio2rdf.org/doid:2377
# http://bio2rdf.org/drugbank:DB01234 http://bio2rdf.org/doid:2377
# http://bio2rdf.org/drugbank:DB00381 http://bio2rdf.org/doid:10763
#  91%|█████████ | 91/100 [00:00<00:00, 184.47it/s]
# http://bio2rdf.org/drugbank:DB01076 http://bio2rdf.org/doid:10763
# http://bio2rdf.org/drugbank:DB00571 http://bio2rdf.org/doid:10763
# 100%|██████████| 100/100 [00:00<00:00, 177.83it/s]

# %%
coverage_check_out, coverage_check = (L_train != ABSTAIN).mean(axis=0)
print(f"check_out coverage: {coverage_check_out * 100:.1f}%")
print(f"check coverage: {coverage_check * 100:.1f}%")
# Out:
# check_out coverage: 6.0%
# check coverage: 69.0%

# %% [markdown]
# ### Defining labeling function for each rule

# %%
# This table is the output of the rule mining tool AIME+ using Hetnet KG
df_rules = pd.read_csv('../data/input/rules-hetionet-edges-20-04-2020.tsv',sep='\t')
df_rules.head()
# Out:
#                                         Rule  Head Coverage  Std Confidence  \
# 0  ?a  CpD  ?f  ?f  DrD  ?b   => ?a  CpD  ?b       0.235897        0.105747
# 1  ?f  CpD  ?b  ?a  CrC  ?f   => ?a  CpD  ?b       0.338462        0.080097
# 2  ?e  CpD  ?b  ?e  CrC  ?a   => ?a  CpD  ?b       0.317949        0.067982
# 3  ?a  DrD  ?f  ?b  DrD  ?f   => ?a  DrD  ?b       0.644567        0.150215
# 4  ?f  DrD  ?b  ?a  DrD  ?f   => ?a  DrD  ?b       0.631676        0.286789
#
#    PCA Confidence  Positive Examples  Body size  PCA Body size  \
# 0        0.105747                 92        870            870
# 1        0.279070                132       1648            473
# 2        0.227106                124       1824            546
# 3        0.150215                350       2330           2330
# 4        0.286789                343       1196           1196
#
#   Functional variable  Std. Lower Bound  PCA Lower Bound  PCA Conf estimation
# 0                  ?a               0.0              0.0                  0.0
# 1                  ?a               0.0              0.0                  0.0
# 2                  ?a               0.0              0.0                  0.0
# 3                  ?a               0.0              0.0                  0.0
# 4                  ?a               0.0              0.0                  0.0

# %% [markdown]
# ### Extract the rules that are related to Compound and Disease (CtD relation)

# %%
rules = []
for rule in df_rules.Rule:
    #print(rule)
    body,head = rule.split(' =>')
    
    #print(head)
    relation = head.split('  ')[1].replace('>','')
    if relation == 'CtD':
        body = body.replace('CtD','<http://bio2rdf.org/hetionet:CtD>').\
        replace('CrC','<http://bio2rdf.org/hetionet:CrC>').\
        replace('DrD','<http://bio2rdf.org/hetionet:DrD>')
        
        head = head.replace('CtD','<http://bio2rdf.org/hetionet:CtD>').\
        replace('CrC','<http://bio2rdf.org/hetionet:CrC>').\
        replace('DrD','<http://bio2rdf.org/hetionet:DrD>')
        print (relation)
        print(body, head)
        rules.append({'head':head, 'body':body, 'relation':'CtD'})
# Out:
# CtD
# ?a  <http://bio2rdf.org/hetionet:CtD>  ?f  ?f  <http://bio2rdf.org/hetionet:DrD>  ?b    ?a  <http://bio2rdf.org/hetionet:CtD>  ?b
# CtD
# ?a  <http://bio2rdf.org/hetionet:CtD>  ?f  ?b  <http://bio2rdf.org/hetionet:DrD>  ?f    ?a  <http://bio2rdf.org/hetionet:CtD>  ?b
# CtD
# ?a  <http://bio2rdf.org/hetionet:CrC>  ?f  ?f  <http://bio2rdf.org/hetionet:CtD>  ?b    ?a  <http://bio2rdf.org/hetionet:CtD>  ?b
# CtD
# ?e  <http://bio2rdf.org/hetionet:CrC>  ?a  ?e  <http://bio2rdf.org/hetionet:CtD>  ?b    ?a  <http://bio2rdf.org/hetionet:CtD>  ?b

# %%
rules
# Out:
# [{'head': ' ?a  <http://bio2rdf.org/hetionet:CtD>  ?b',
#   'body': '?a  <http://bio2rdf.org/hetionet:CtD>  ?f  ?f  <http://bio2rdf.org/hetionet:DrD>  ?b  ',
#   'relation': 'CtD'},
#  {'head': ' ?a  <http://bio2rdf.org/hetionet:CtD>  ?b',
#   'body': '?a  <http://bio2rdf.org/hetionet:CtD>  ?f  ?b  <http://bio2rdf.org/hetionet:DrD>  ?f  ',
#   'relation': 'CtD'},
#  {'head': ' ?a  <http://bio2rdf.org/hetionet:CtD>  ?b',
#   'body': '?a  <http://bio2rdf.org/hetionet:CrC>  ?f  ?f  <http://bio2rdf.org/hetionet:CtD>  ?b  ',
#   'relation': 'CtD'},
#  {'head': ' ?a  <http://bio2rdf.org/hetionet:CtD>  ?b',
#   'body': '?e  <http://bio2rdf.org/hetionet:CrC>  ?a  ?e  <http://bio2rdf.org/hetionet:CtD>  ?b  ',
#   'relation': 'CtD'}]

# %%
! pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.0.1-cp37-cp37m-manylinux1_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 12.1 MB/s eta 0:00:01
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.1.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 12.2 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.18.1 in /workspace/anaconda3/envs/bio/lib/python3.7/site-packages (from gensim) (1.6.2)
# Requirement already satisfied: numpy>=1.11.3 in /workspace/anaconda3/envs/bio/lib/python3.7/site-packages (from gensim) (1.20.2)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/workspace/anaconda3/envs/bio/lib/python3.7/site-packages/numpy-1.20.2.dist-info/METADATA'

# %% [markdown]
# ### Embedding

# %%
# from gensim.models import KeyedVectors

# %%
word_vectors = KeyedVectors.load('../embeddings/hetionet/w2v_vectors.kv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-bcf7c048dc5e> in <module>
# ----> 1 word_vectors = KeyedVectors.load('../embeddings/hetionet/w2v_vectors.kv')
#
# NameError: name 'KeyedVectors' is not defined

# %% [markdown]
# ### Convert the rules to SPARQL queries

# %%
def construct_query_for_rule(rule):
    patterns = rule['body'].split('  ')
    n_pattern = len(patterns)
    triple_pattern = """SELECT DISTINCT ?a ?b where { 
      
    """
    k =3
    for i in range(int(n_pattern/k)):
        triple_pattern += patterns[i*k] + ' '+patterns[k*i+1] + ' '+patterns[k*i+2] +' . \n'
        #print (triple_pattern)

    triple_pattern+= "MINUS {"+rule['head']+" .}"
    triple_pattern+= """
    }"""
    return triple_pattern

# %%
sparql0 = construct_query_for_rule(rules[0])
sparql0
qres0 = g.query(sparql0)

# %%
sparql1 = construct_query_for_rule(rules[1])
qres1 = g.query(sparql1)
sparql1
# Out:
# 'SELECT DISTINCT ?a ?b where { \n      \n    ?a <http://bio2rdf.org/hetionet:CtD> ?f . \n?b <http://bio2rdf.org/hetionet:DrD> ?f . \nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'

# %%
sparql2 = construct_query_for_rule(rules[2])
qres2 = g.query(sparql2)
sparql2
# Out:
# 'SELECT DISTINCT ?a ?b where { \n      \n    ?a <http://bio2rdf.org/hetionet:CrC> ?f . \n?f <http://bio2rdf.org/hetionet:CtD> ?b . \nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'

# %%
sparql3 = construct_query_for_rule(rules[3])
qres3 = g.query(sparql3)
sparql3
# Out:
# 'SELECT DISTINCT ?a ?b where { \n      \n    ?e <http://bio2rdf.org/hetionet:CrC> ?a . \n?e <http://bio2rdf.org/hetionet:CtD> ?b . \nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'

# %% [markdown]
# ### Use the SPARQL query results in the labeling fuctions
# If the SPARQL results defined for a rule contain a drug and disease pair, it means this rule supports the fact that the drug treats the target

# %%
@labeling_function()
def check_rule0(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres0:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            return INDICATION
    return ABSTAIN


@labeling_function()
def check_rule1(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres1:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            return INDICATION
    return ABSTAIN

@labeling_function()
def check_rule2(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres2:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            return INDICATION
    return ABSTAIN

@labeling_function()
def check_rule3(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres2:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            return INDICATION
    return ABSTAIN


@labeling_function()
def check_phrase(x):
    if str(x.Context) !='nan':
        text = x.Context.lower()
        #print ('text')
        for phr in treatment_phrases:
            if phr in text:
                return INDICATION
    return ABSTAIN

# %%
# Use Embedding model in the labeling function  
! pip install csv
# Out:
# ERROR: Could not find a version that satisfies the requirement csv
# ERROR: No matching distribution found for csv

# %%
import numpy as np
import csv

entity_emb = np.load('../embeddings/embed/hetionet_TransE_l2_entity.npy')
relation_emb = np.load('../embeddings/embed/hetionet_TransE_l2_relation.npy')

entity_idmap_file = '../embeddings/hetionet/entities.tsv'
relation_idmap_file = '../embeddings/hetionet/relations.tsv'

entity_map = {}
entity_id_map = {}
relation_map = {}
with open(entity_idmap_file, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t', fieldnames=['id','name'])
    for row_val in reader:
        entity_map[row_val['name']] = int(row_val['id'])
        entity_id_map[int(row_val['id'])] = row_val['name']
        
with open(relation_idmap_file, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t', fieldnames=['id','name'])
    for row_val in reader:
        relation_map[row_val['name']] = int(row_val['id'])    
entity_map
# Out:
# {'Anatomy::UBERON:0001295': 0,
#  'Gene::6954': 1,
#  'Anatomy::UBERON:0000473': 2,
#  'Gene::127845': 3,
#  'Anatomy::UBERON:0002185': 4,
#  'Gene::11346': 5,
#  'Gene::7424': 6,
#  'Biological Process::GO:0045776': 7,
#  'Gene::4297': 8,
#  'Gene::8351': 9,
#  'Compound::DB00635': 10,
#  'Side Effect::C0042384': 11,
#  'Gene::200879': 12,
#  'Gene::10610': 13,
#  'Anatomy::UBERON:0001296': 14,
#  'Gene::55159': 15,
#  'Anatomy::UBERON:0000998': 16,
#  'Gene::1359': 17,
#  'Gene::10472': 18,
#  'Gene::2771': 19,
#  'Gene::1244': 20,
#  'Gene::5607': 21,
#  'Gene::3988': 22,
#  'Gene::9641': 23,
#  'Gene::6134': 24,
#  'Gene::7412': 25,
#  'Gene::322': 26,
#  'Biological Process::GO:0051054': 27,
#  'Gene::64064': 28,
#  'Molecular Function::GO:0008260': 29,
#  'Compound::DB00667': 30,
#  'Side Effect::C0032343': 31,
#  'Gene::5252': 32,
#  'Biological Process::GO:0031061': 33,
#  'Gene::79649': 34,
#  'Cellular Component::GO:0005815': 35,
#  'Gene::2079': 36,
#  'Gene::3108': 37,
#  'Gene::51444': 38,
#  'Biological Process::GO:0070647': 39,
#  'Compound::DB08868': 40,
#  'Side Effect::C0038454': 41,
#  'Gene::8898': 42,
#  'Biological Process::GO:0031644': 43,
#  'Gene::6191': 44,
#  'Cellular Component::GO:0022626': 45,
#  'Gene::51400': 46,
#  'Anatomy::UBERON:0000991': 47,
#  'Gene::6167': 48,
#  'Gene::8731': 49,
#  'Biological Process::GO:0036265': 50,
#  'Gene::6608': 51,
#  'Biological Process::GO:0007228': 52,
#  'Gene::8872': 53,
#  'Gene::7157': 54,
#  'Gene::10273': 55,
#  'Gene::8061': 56,
#  'Biological Process::GO:0031960': 57,
#  'Gene::1649': 58,
#  'Biological Process::GO:0044257': 59,
#  'Gene::22920': 60,
#  'Pathway::PC7_4688': 61,
#  'Anatomy::UBERON:0003126': 62,
#  'Gene::23231': 63,
#  'Anatomy::UBERON:0002107': 64,
#  'Gene::23135': 65,
#  'Gene::54658': 66,
#  'Biological Process::GO:0045833': 67,
#  'Gene::80830': 68,
#  'Gene::5076': 69,
#  'Biological Process::GO:0048596': 70,
#  'Gene::29978': 71,
#  'Biological Process::GO:0045745': 72,
#  'Gene::25759': 73,
#  'Pathway::WP673_r80202': 74,
#  'Gene::5648': 75,
#  'Gene::8452': 76,
#  'Pharmacologic Class::N0000175372': 77,
#  'Compound::DB00191': 78,
#  'Anatomy::UBERON:0000057': 79,
#  'Gene::4016': 80,
#  'Gene::5581': 81,
#  'Biological Process::GO:0060193': 82,
#  'Anatomy::UBERON:0002367': 83,
#  'Gene::56895': 84,
#  'Gene::7846': 85,
#  'Gene::27183': 86,
#  'Gene::7375': 87,
#  'Gene::10075': 88,
#  'Anatomy::UBERON:0000029': 89,
#  'Gene::64411': 90,
#  'Gene::323': 91,
#  'Biological Process::GO:0030198': 92,
#  'Gene::151531': 93,
#  'Biological Process::GO:0009218': 94,
#  'Anatomy::UBERON:0000997': 95,
#  'Gene::287': 96,
#  'Gene::8829': 97,
#  'Biological Process::GO:0070372': 98,
#  'Gene::79814': 99,
#  'Molecular Function::GO:0016813': 100,
#  'Gene::163': 101,
#  'Gene::9729': 102,
#  'Gene::80216': 103,
#  'Gene::29083': 104,
#  'Anatomy::UBERON:0000178': 105,
#  'Gene::10219': 106,
#  'Gene::5781': 107,
#  'Biological Process::GO:0045859': 108,
#  'Gene::9618': 109,
#  'Gene::10409': 110,
#  'Anatomy::UBERON:0000948': 111,
#  'Gene::8612': 112,
#  'Compound::DB00412': 113,
#  'Gene::1565': 114,
#  'Compound::DB00441': 115,
#  'Gene::3107': 116,
#  'Anatomy::UBERON:0000955': 117,
#  'Gene::493860': 118,
#  'Gene::8626': 119,
#  'Gene::55728': 120,
#  'Gene::26': 121,
#  'Biological Process::GO:0071407': 122,
#  'Gene::6642': 123,
#  'Gene::23204': 124,
#  'Compound::DB00591': 125,
#  'Side Effect::C0037199': 126,
#  'Gene::29945': 127,
#  'Biological Process::GO:0051983': 128,
#  'Anatomy::UBERON:0002450': 129,
#  'Gene::65056': 130,
#  'Anatomy::UBERON:0001231': 131,
#  'Gene::7515': 132,
#  'Anatomy::UBERON:0002240': 133,
#  'Gene::84246': 134,
#  'Gene::400073': 135,
#  'Gene::7465': 136,
#  'Gene::11284': 137,
#  'Gene::23252': 138,
#  'Gene::23154': 139,
#  'Anatomy::UBERON:0000474': 140,
#  'Gene::29126': 141,
#  'Gene::2113': 142,
#  'Gene::2063': 143,
#  'Gene::57148': 144,
#  'Biological Process::GO:0007264': 145,
#  'Gene::2877': 146,
#  'Gene::22934': 147,
#  'Gene::4641': 148,
#  'Molecular Function::GO:0016818': 149,
#  'Gene::342184': 150,
#  'Biological Process::GO:0072028': 151,
#  'Biological Process::GO:1903827': 152,
#  'Gene::7224': 153,
#  'Biological Process::GO:0098771': 154,
#  'Compound::DB00738': 155,
#  'Side Effect::C0042571': 156,
#  'Gene::813': 157,
#  'Gene::8030': 158,
#  'Gene::4905': 159,
#  'Gene::5800': 160,
#  'Gene::53615': 161,
#  'Biological Process::GO:0006342': 162,
#  'Gene::821': 163,
#  'Gene::7276': 164,
#  'Gene::23545': 165,
#  'Molecular Function::GO:0015399': 166,
#  'Gene::8648': 167,
#  'Gene::10011': 168,
#  'Disease::DOID:3083': 169,
#  'Gene::55198': 170,
#  'Gene::85358': 171,
#  'Biological Process::GO:0072657': 172,
#  'Anatomy::UBERON:0000483': 173,
#  'Gene::1479': 174,
#  'Gene::7743': 175,
#  'Biological Process::GO:0000423': 176,
#  'Gene::6491': 177,
#  'Gene::79143': 178,
#  'Gene::84698': 179,
#  'Gene::7124': 180,
#  'Biological Process::GO:0017038': 181,
#  'Gene::51412': 182,
#  'Cellular Component::GO:0090544': 183,
#  'Anatomy::UBERON:0001017': 184,
#  'Gene::57669': 185,
#  'Gene::4957': 186,
#  'Gene::54681': 187,
#  'Gene::9276': 188,
#  'Gene::55193': 189,
#  'Gene::991': 190,
#  'Gene::30': 191,
#  'Gene::51719': 192,
#  'Anatomy::UBERON:0000970': 193,
#  'Gene::408050': 194,
#  'Gene::4969': 195,
#  'Biological Process::GO:0007409': 196,
#  'Compound::DB00680': 197,
#  'Compound::DB00850': 198,
#  'Anatomy::UBERON:0000033': 199,
#  'Gene::115703': 200,
#  'Gene::9134': 201,
#  'Pathway::PC7_2519': 202,
#  'Gene::610': 203,
#  'Pathway::WP1992_r78296': 204,
#  'Gene::23054': 205,
#  'Biological Process::GO:0002791': 206,
#  'Anatomy::UBERON:0002368': 207,
#  'Gene::3883': 208,
#  'Gene::1571': 209,
#  'Anatomy::UBERON:0001044': 210,
#  'Gene::22902': 211,
#  'Gene::5367': 212,
#  'Pathway::PC7_7457': 213,
#  'Gene::266675': 214,
#  'Gene::26038': 215,
#  'Biological Process::GO:0070734': 216,
#  'Gene::1950': 217,
#  'Anatomy::UBERON:0001021': 218,
#  'Gene::3363': 219,
#  'Gene::6990': 220,
#  'Gene::7923': 221,
#  'Gene::92270': 222,
#  'Cellular Component::GO:0016469': 223,
#  'Gene::51564': 224,
#  'Pathway::PC7_2681': 225,
#  'Gene::54997': 226,
#  'Biological Process::GO:0030097': 227,
#  'Gene::7874': 228,
#  'Gene::5250': 229,
#  'Gene::28960': 230,
#  'Compound::DB00295': 231,
#  'Side Effect::C0041834': 232,
#  'Gene::2671': 233,
#  'Cellular Component::GO:0031970': 234,
#  'Gene::152519': 235,
#  'Molecular Function::GO:0022857': 236,
#  'Gene::9915': 237,
#  'Gene::5434': 238,
#  'Gene::1909': 239,
#  'Biological Process::GO:0032504': 240,
#  'Compound::DB01030': 241,
#  'Gene::4616': 242,
#  'Compound::DB00961': 243,
#  'Side Effect::C0027769': 244,
#  'Compound::DB00778': 245,
#  'Side Effect::C0030554': 246,
#  'Gene::10059': 247,
#  'Gene::7128': 248,
#  'Biological Process::GO:0090289': 249,
#  'Anatomy::UBERON:0000992': 250,
#  'Gene::594': 251,
#  'Gene::7574': 252,
#  'Gene::121274': 253,
#  'Gene::134353': 254,
#  'Molecular Function::GO:0071209': 255,
#  'Gene::351': 256,
#  'Gene::8412': 257,
#  'Gene::80326': 258,
#  'Cellular Component::GO:0031012': 259,
#  'Anatomy::UBERON:0001135': 260,
#  'Gene::7291': 261,
#  'Anatomy::UBERON:0000996': 262,
#  'Gene::55974': 263,
#  'Gene::3158': 264,
#  'Biological Process::GO:0008610': 265,
#  'Gene::2697': 266,
#  'Biological Process::GO:0015931': 267,
#  'Gene::79132': 268,
#  'Biological Process::GO:0039536': 269,
#  'Gene::6124': 270,
#  'Gene::6202': 271,
#  'Gene::54469': 272,
#  'Gene::79921': 273,
#  'Anatomy::UBERON:0002046': 274,
#  'Gene::8813': 275,
#  'Gene::84549': 276,
#  'Gene::4720': 277,
#  'Gene::55206': 278,
#  'Gene::116540': 279,
#  'Biological Process::GO:0022411': 280,
#  'Gene::7280': 281,
#  'Gene::29796': 282,
#  'Anatomy::UBERON:0001891': 283,
#  'Gene::55717': 284,
#  'Gene::9529': 285,
#  'Disease::DOID:5419': 286,
#  'Gene::727957': 287,
#  'Gene::10524': 288,
#  'Biological Process::GO:0018394': 289,
#  'Anatomy::UBERON:0002048': 290,
#  'Gene::23399': 291,
#  'Gene::148867': 292,
#  'Gene::153339': 293,
#  'Gene::6194': 294,
#  'Gene::81579': 295,
#  'Gene::4190': 296,
#  'Gene::54407': 297,
#  'Anatomy::UBERON:0001895': 298,
#  'Gene::9267': 299,
#  'Gene::6201': 300,
#  'Gene::23450': 301,
#  'Gene::150': 302,
#  'Compound::DB04573': 303,
#  'Gene::22887': 304,
#  'Compound::DB08893': 305,
#  'Side Effect::C0000737': 306,
#  'Gene::8837': 307,
#  'Biological Process::GO:0055001': 308,
#  'Gene::7343': 309,
#  'Gene::23378': 310,
#  'Gene::392391': 311,
#  'Gene::10943': 312,
#  'Gene::375346': 313,
#  'Gene::100129583': 314,
#  'Gene::7153': 315,
#  'Gene::5223': 316,
#  'Gene::481': 317,
#  'Gene::4121': 318,
#  'Gene::5023': 319,
#  'Molecular Function::GO:0022890': 320,
#  'Gene::5230': 321,
#  'Gene::23097': 322,
#  'Gene::3066': 323,
#  'Gene::4830': 324,
#  'Compound::DB00694': 325,
#  'Gene::5427': 326,
#  'Gene::8703': 327,
#  'Gene::960': 328,
#  'Gene::3663': 329,
#  'Gene::54205': 330,
#  'Gene::5695': 331,
#  'Biological Process::GO:0090316': 332,
#  'Gene::152789': 333,
#  'Gene::2050': 334,
#  'Pathway::PC7_3420': 335,
#  'Gene::58480': 336,
#  'Gene::126626': 337,
#  'Gene::6390': 338,
#  'Gene::3912': 339,
#  'Biological Process::GO:0007566': 340,
#  'Gene::2491': 341,
#  'Biological Process::GO:0016568': 342,
#  'Gene::6208': 343,
#  'Biological Process::GO:0042274': 344,
#  'Gene::3569': 345,
#  'Biological Process::GO:0042493': 346,
#  'Gene::50814': 347,
#  'Biological Process::GO:0006694': 348,
#  'Gene::55017': 349,
#  'Gene::1437': 350,
#  'Biological Process::GO:0048667': 351,
#  'Anatomy::UBERON:0002390': 352,
#  'Gene::4140': 353,
#  'Anatomy::UBERON:0001008': 354,
#  'Gene::6938': 355,
#  'Gene::3303': 356,
#  'Gene::10392': 357,
#  'Gene::1453': 358,
#  'Biological Process::GO:0009100': 359,
#  'Compound::DB00476': 360,
#  'Side Effect::C0277925': 361,
#  'Gene::10533': 362,
#  'Biological Process::GO:0051146': 363,
#  'Anatomy::UBERON:0001016': 364,
#  'Compound::DB00620': 365,
#  'Gene::4088': 366,
#  'Gene::6229': 367,
#  'Gene::29894': 368,
#  'Pathway::PC7_6534': 369,
#  'Anatomy::UBERON:0002037': 370,
#  'Gene::51027': 371,
#  'Gene::1339': 372,
#  'Molecular Function::GO:0015002': 373,
#  'Anatomy::UBERON:0001846': 374,
#  'Gene::2299': 375,
#  'Gene::5189': 376,
#  'Gene::10225': 377,
#  'Gene::9922': 378,
#  'Gene::113': 379,
#  'Pathway::PC7_5322': 380,
#  'Gene::1936': 381,
#  'Gene::7353': 382,
#  'Gene::4885': 383,
#  'Gene::27236': 384,
#  'Gene::1763': 385,
#  'Biological Process::GO:0019439': 386,
#  'Gene::64792': 387,
#  'Anatomy::UBERON:0001893': 388,
#  'Gene::10276': 389,
#  'Compound::DB00091': 390,
#  'Gene::6747': 391,
#  'Anatomy::UBERON:0002371': 392,
#  'Gene::1786': 393,
#  'Gene::5635': 394,
#  'Cellular Component::GO:0002189': 395,
#  'Gene::6733': 396,
#  'Gene::7422': 397,
#  'Biological Process::GO:0060754': 398,
#  'Gene::4043': 399,
#  'Biological Process::GO:0051098': 400,
#  'Gene::84225': 401,
#  'Gene::5318': 402,
#  'Biological Process::GO:0086004': 403,
#  'Gene::54187': 404,
#  'Biological Process::GO:0043687': 405,
#  'Gene::643803': 406,
#  'Gene::29106': 407,
#  'Gene::10298': 408,
#  'Gene::25966': 409,
#  'Compound::DB01204': 410,
#  'Gene::5440': 411,
#  'Gene::3295': 412,
#  'Biological Process::GO:0072329': 413,
#  'Gene::6277': 414,
#  'Anatomy::UBERON:0002082': 415,
#  'Gene::6917': 416,
#  'Gene::2342': 417,
#  'Anatomy::UBERON:0000002': 418,
#  'Gene::10809': 419,
#  'Gene::5700': 420,
#  'Pathway::PC7_5530': 421,
#  'Gene::6611': 422,
#  'Gene::3726': 423,
#  'Gene::27072': 424,
#  'Anatomy::UBERON:0002030': 425,
#  'Gene::57216': 426,
#  'Gene::60491': 427,
#  'Gene::1499': 428,
#  'Biological Process::GO:0001759': 429,
#  'Gene::8454': 430,
#  'Gene::26517': 431,
#  'Anatomy::UBERON:0001264': 432,
#  'Gene::54951': 433,
#  'Gene::2266': 434,
#  'Biological Process::GO:0003018': 435,
#  'Compound::DB01240': 436,
#  'Side Effect::C0020517': 437,
#  'Gene::10204': 438,
#  'Biological Process::GO:1903651': 439,
#  'Gene::54788': 440,
#  'Gene::353133': 441,
#  'Gene::55156': 442,
#  'Gene::126231': 443,
#  'Gene::8787': 444,
#  'Gene::5054': 445,
#  'Biological Process::GO:0040013': 446,
#  'Gene::182': 447,
#  'Biological Process::GO:0035315': 448,
#  'Gene::147111': 449,
#  'Molecular Function::GO:0016788': 450,
#  'Gene::758': 451,
#  'Gene::4502': 452,
#  'Gene::3156': 453,
#  'Gene::153020': 454,
#  'Cellular Component::GO:0030496': 455,
#  'Biological Process::GO:0001763': 456,
#  'Gene::2627': 457,
#  'Gene::55131': 458,
#  'Biological Process::GO:0008380': 459,
#  'Gene::29902': 460,
#  'Gene::58506': 461,
#  'Compound::DB04841': 462,
#  'Gene::10873': 463,
#  'Gene::6304': 464,
#  'Anatomy::UBERON:0002081': 465,
#  'Gene::51256': 466,
#  'Gene::3198': 467,
#  'Gene::7298': 468,
#  'Compound::DB00989': 469,
#  'Side Effect::C0008350': 470,
#  'Gene::4994': 471,
#  'Biological Process::GO:0007600': 472,
#  'Anatomy::UBERON:0001831': 473,
#  'Gene::23141': 474,
#  'Gene::114026': 475,
#  'Gene::5018': 476,
#  'Gene::3785': 477,
#  'Gene::579': 478,
#  'Gene::7349': 479,
#  'Gene::113451': 480,
#  'Cellular Component::GO:0030425': 481,
#  'Gene::27243': 482,
#  'Gene::3240': 483,
#  'Anatomy::UBERON:0002097': 484,
#  'Gene::200315': 485,
#  'Anatomy::UBERON:0002369': 486,
#  'Gene::5164': 487,
#  'Gene::54551': 488,
#  'Cellular Component::GO:0005769': 489,
#  'Gene::2588': 490,
#  'Cellular Component::GO:0000323': 491,
#  'Gene::7357': 492,
#  'Gene::1788': 493,
#  'Pathway::PC7_5307': 494,
#  'Gene::127943': 495,
#  'Gene::81844': 496,
#  'Biological Process::GO:0009607': 497,
#  'Gene::8269': 498,
#  'Gene::10250': 499,
#  'Gene::5831': 500,
#  'Gene::25897': 501,
#  'Biological Process::GO:0031331': 502,
#  'Gene::3630': 503,
#  'Biological Process::GO:0070873': 504,
#  'Gene::8125': 505,
#  'Gene::8368': 506,
#  'Gene::84701': 507,
#  'Gene::129531': 508,
#  'Compound::DB00959': 509,
#  'Side Effect::C0235409': 510,
#  'Gene::1130': 511,
#  'Gene::64210': 512,
#  'Molecular Function::GO:0051427': 513,
#  'Gene::51560': 514,
#  'Molecular Function::GO:0031489': 515,
#  'Gene::219749': 516,
#  'Gene::8527': 517,
#  'Gene::8189': 518,
#  'Gene::3484': 519,
#  'Pathway::PC7_1181': 520,
#  'Gene::138050': 521,
#  'Gene::440387': 522,
#  'Gene::54870': 523,
#  'Gene::4234': 524,
#  'Gene::81627': 525,
#  'Gene::5172': 526,
#  'Molecular Function::GO:0015297': 527,
#  'Gene::3709': 528,
#  'Biological Process::GO:0010243': 529,
#  'Gene::55212': 530,
#  'Cellular Component::GO:0005813': 531,
#  'Gene::56474': 532,
#  'Biological Process::GO:0006213': 533,
#  'Gene::3827': 534,
#  'Biological Process::GO:0035150': 535,
#  'Gene::6233': 536,
#  'Pathway::PC7_1552': 537,
#  'Gene::79934': 538,
#  'Gene::92196': 539,
#  'Molecular Function::GO:0019904': 540,
#  'Compound::DB01002': 541,
#  'Side Effect::C0036974': 542,
#  'Gene::197135': 543,
#  'Biological Process::GO:0046700': 544,
#  'Gene::81876': 545,
#  'Biological Process::GO:0070085': 546,
#  'Gene::220': 547,
#  'Biological Process::GO:0042574': 548,
#  'Gene::55332': 549,
#  'Gene::2248': 550,
#  'Biological Process::GO:0048598': 551,
#  'Gene::6232': 552,
#  'Gene::25': 553,
#  'Gene::3508': 554,
#  'Gene::51283': 555,
#  'Biological Process::GO:0006511': 556,
#  'Gene::7818': 557,
#  'Biological Process::GO:0006518': 558,
#  'Gene::161829': 559,
#  'Compound::DB00661': 560,
#  'Gene::776': 561,
#  'Gene::7538': 562,
#  'Gene::2305': 563,
#  'Gene::6347': 564,
#  'Biological Process::GO:0019079': 565,
#  'Gene::7060': 566,
#  'Gene::18': 567,
#  'Disease::DOID:7148': 568,
#  'Gene::2186': 569,
#  'Compound::DB09020': 570,
#  'Gene::587': 571,
#  'Gene::7592': 572,
#  'Gene::60685': 573,
#  'Gene::3746': 574,
#  'Molecular Function::GO:0015075': 575,
#  'Compound::DB01149': 576,
#  'Side Effect::C0037763': 577,
#  'Compound::DB00564': 578,
#  'Side Effect::C0004604': 579,
#  'Gene::5612': 580,
#  'Gene::7057': 581,
#  'Gene::57192': 582,
#  'Gene::5350': 583,
#  'Biological Process::GO:0072511': 584,
#  'Gene::4594': 585,
#  'Biological Process::GO:0016054': 586,
#  'Gene::8497': 587,
#  'Biological Process::GO:0046903': 588,
#  'Gene::400793': 589,
#  'Gene::282890': 590,
#  'Gene::847': 591,
#  'Pathway::PC7_3083': 592,
#  'Gene::51514': 593,
#  'Biological Process::GO:1904666': 594,
#  'Anatomy::UBERON:0001675': 595,
#  'Gene::688': 596,
#  'Gene::56005': 597,
#  'Biological Process::GO:0045765': 598,
#  'Anatomy::UBERON:0002349': 599,
#  'Gene::8721': 600,
#  'Gene::4255': 601,
#  'Gene::3737': 602,
#  'Gene::5092': 603,
#  'Gene::6301': 604,
#  'Gene::51162': 605,
#  'Biological Process::GO:0050678': 606,
#  'Gene::5879': 607,
#  'Biological Process::GO:0051893': 608,
#  'Compound::DB00773': 609,
#  'Side Effect::C3160947': 610,
#  'Compound::DB04896': 611,
#  'Side Effect::C0040822': 612,
#  'Compound::DB08873': 613,
#  'Side Effect::C0014541': 614,
#  'Gene::4292': 615,
#  'Gene::4683': 616,
#  'Gene::23613': 617,
#  'Gene::7165': 618,
#  'Gene::64794': 619,
#  'Molecular Function::GO:0019955': 620,
#  'Gene::123099': 621,
#  'Molecular Function::GO:0016705': 622,
#  'Gene::9252': 623,
#  'Biological Process::GO:0045088': 624,
#  'Gene::81532': 625,
#  'Compound::DB08899': 626,
#  'Gene::3237': 627,
#  'Gene::2091': 628,
#  'Gene::30968': 629,
#  'Gene::122402': 630,
#  'Gene::2886': 631,
#  'Gene::79583': 632,
#  'Cellular Component::GO:0060170': 633,
#  'Compound::DB00446': 634,
#  'Side Effect::C0033774': 635,
#  'Gene::23165': 636,
#  'Gene::8293': 637,
#  'Anatomy::UBERON:0001225': 638,
#  'Gene::254295': 639,
#  'Gene::1903': 640,
#  'Gene::1445': 641,
#  'Gene::9261': 642,
#  'Gene::51367': 643,
#  'Biological Process::GO:0006396': 644,
#  'Gene::6521': 645,
#  'Biological Process::GO:0006873': 646,
#  'Gene::3127': 647,
#  'Molecular Function::GO:0042277': 648,
#  'Gene::11097': 649,
#  'Gene::80380': 650,
#  'Biological Process::GO:0032944': 651,
#  'Gene::10576': 652,
#  'Biological Process::GO:0032204': 653,
#  'Gene::6228': 654,
#  'Gene::9775': 655,
#  'Gene::10023': 656,
#  'Pathway::PC7_6815': 657,
#  'Gene::23099': 658,
#  'Gene::79710': 659,
#  'Gene::10269': 660,
#  'Gene::3735': 661,
#  'Gene::6154': 662,
#  'Gene::51776': 663,
#  'Biological Process::GO:0032147': 664,
#  'Gene::6550': 665,
#  'Biological Process::GO:0015672': 666,
#  'Gene::51187': 667,
#  'Gene::9687': 668,
#  'Gene::55699': 669,
#  'Anatomy::UBERON:0001004': 670,
#  'Gene::51447': 671,
#  'Gene::6520': 672,
#  'Gene::23612': 673,
#  'Compound::DB00937': 674,
#  'Side Effect::C0013384': 675,
#  'Gene::29078': 676,
#  'Gene::5216': 677,
#  'Gene::23522': 678,
#  'Gene::3105': 679,
#  'Gene::10288': 680,
#  'Gene::6609': 681,
#  'Biological Process::GO:1902532': 682,
#  'Gene::57017': 683,
#  'Biological Process::GO:0072521': 684,
#  'Gene::79180': 685,
#  'Gene::6041': 686,
#  'Biological Process::GO:0043900': 687,
#  'Gene::56956': 688,
#  'Gene::5479': 689,
#  'Gene::54920': 690,
#  'Gene::1958': 691,
#  'Gene::93185': 692,
#  'Gene::2355': 693,
#  'Pathway::PC7_8681': 694,
#  'Gene::27010': 695,
#  'Compound::DB00915': 696,
#  'Gene::64123': 697,
#  'Gene::4817': 698,
#  'Gene::3930': 699,
#  'Gene::90678': 700,
#  'Biological Process::GO:0080135': 701,
#  'Compound::DB00482': 702,
#  'Side Effect::C0019158': 703,
#  'Gene::2734': 704,
#  'Biological Process::GO:0042060': 705,
#  'Gene::64710': 706,
#  'Compound::DB01175': 707,
#  'Side Effect::C0542476': 708,
#  'Gene::80310': 709,
#  'Biological Process::GO:0009161': 710,
#  'Gene::5469': 711,
#  'Biological Process::GO:0048736': 712,
#  'Gene::169355': 713,
#  'Biological Process::GO:0042402': 714,
#  'Gene::984': 715,
#  'Gene::2021': 716,
#  'Gene::79628': 717,
#  'Gene::492311': 718,
#  'Gene::3065': 719,
#  'Gene::5934': 720,
#  'Gene::864': 721,
#  'Gene::4925': 722,
#  'Gene::7167': 723,
#  'Gene::79073': 724,
#  'Compound::DB00404': 725,
#  'Side Effect::C0236075': 726,
#  'Gene::8874': 727,
#  'Gene::84249': 728,
#  'Compound::DB04865': 729,
#  'Gene::22926': 730,
#  'Anatomy::UBERON:0001969': 731,
#  'Gene::2193': 732,
#  'Gene::5446': 733,
#  'Gene::3628': 734,
#  'Gene::5347': 735,
#  'Gene::79581': 736,
#  'Gene::4846': 737,
#  'Disease::DOID:2986': 738,
#  'Gene::26051': 739,
#  'Gene::5577': 740,
#  'Cellular Component::GO:0098857': 741,
#  'Gene::51686': 742,
#  'Biological Process::GO:0015847': 743,
#  'Anatomy::UBERON:0000995': 744,
#  'Gene::6788': 745,
#  'Gene::55207': 746,
#  'Cellular Component::GO:0098852': 747,
#  'Gene::8974': 748,
#  'Gene::79567': 749,
#  'Gene::3689': 750,
#  'Gene::5583': 751,
#  'Gene::5521': 752,
#  'Gene::6470': 753,
#  'Biological Process::GO:0009221': 754,
#  'Gene::4775': 755,
#  'Gene::2081': 756,
#  'Molecular Function::GO:0030544': 757,
#  'Gene::2475': 758,
#  'Gene::4735': 759,
#  'Gene::5591': 760,
#  'Biological Process::GO:0043066': 761,
#  'Gene::9219': 762,
#  'Gene::6697': 763,
#  'Gene::8073': 764,
#  'Compound::DB00704': 765,
#  'Side Effect::C0039070': 766,
#  'Gene::7498': 767,
#  'Biological Process::GO:0010563': 768,
#  'Gene::1890': 769,
#  'Biological Process::GO:0001568': 770,
#  'Anatomy::UBERON:0000966': 771,
#  'Gene::58472': 772,
#  'Compound::DB06589': 773,
#  'Side Effect::C0860871': 774,
#  'Gene::10519': 775,
#  'Cellular Component::GO:0030426': 776,
#  'Gene::85480': 777,
#  'Gene::5522': 778,
#  'Gene::55038': 779,
#  'Gene::1389': 780,
#  'Gene::56851': 781,
#  'Gene::83394': 782,
#  'Biological Process::GO:0006820': 783,
#  'Gene::5771': 784,
#  'Gene::3955': 785,
#  'Biological Process::GO:0009792': 786,
#  'Disease::DOID:0050742': 787,
#  'Gene::92737': 788,
#  'Gene::6207': 789,
#  'Gene::4694': 790,
#  'Gene::7335': 791,
#  'Molecular Function::GO:0004842': 792,
#  'Disease::DOID:13223': 793,
#  'Gene::1586': 794,
#  'Gene::10284': 795,
#  'Gene::5720': 796,
#  'Compound::DB08912': 797,
#  'Gene::9052': 798,
#  'Anatomy::UBERON:0001690': 799,
#  'Gene::57053': 800,
#  'Gene::10046': 801,
#  'Gene::83444': 802,
#  'Gene::7482': 803,
#  'Gene::22987': 804,
#  'Pathway::PC7_3278': 805,
#  'Gene::79651': 806,
#  'Gene::57647': 807,
#  'Molecular Function::GO:0004004': 808,
#  'Gene::54875': 809,
#  'Molecular Function::GO:0000155': 810,
#  'Gene::3269': 811,
#  'Pathway::WP58_r80015': 812,
#  'Gene::23239': 813,
#  'Gene::3795': 814,
#  'Biological Process::GO:0010035': 815,
#  'Gene::3326': 816,
#  'Gene::5693': 817,
#  'Pathway::PC7_1132': 818,
#  'Gene::10488': 819,
#  'Gene::202052': 820,
#  'Compound::DB01104': 821,
#  'Side Effect::C0015672': 822,
#  'Gene::166': 823,
#  'Biological Process::GO:0031668': 824,
#  'Gene::1509': 825,
#  'Molecular Function::GO:0004175': 826,
#  'Gene::5287': 827,
#  'Gene::54517': 828,
#  'Gene::6907': 829,
#  'Gene::5916': 830,
#  'Gene::11065': 831,
#  'Gene::6696': 832,
#  'Gene::1131': 833,
#  'Cellular Component::GO:0036477': 834,
#  'Gene::6768': 835,
#  'Compound::DB00674': 836,
#  'Side Effect::C0017178': 837,
#  'Gene::3875': 838,
#  'Gene::3778': 839,
#  'Gene::1917': 840,
#  'Gene::6185': 841,
#  'Gene::4842': 842,
#  'Biological Process::GO:0042312': 843,
#  'Gene::9743': 844,
#  'Gene::2296': 845,
#  'Molecular Function::GO:0000977': 846,
#  'Gene::5438': 847,
#  'Pathway::PC7_8710': 848,
#  'Gene::4711': 849,
#  'Gene::5058': 850,
#  'Biological Process::GO:0061117': 851,
#  'Gene::3456': 852,
#  'Gene::51316': 853,
#  'Gene::8832': 854,
#  'Anatomy::UBERON:0001896': 855,
#  'Gene::79846': 856,
#  'Compound::DB00921': 857,
#  'Side Effect::C0020649': 858,
#  'Gene::23787': 859,
#  'Gene::55337': 860,
#  'Anatomy::UBERON:0000006': 861,
#  'Gene::23547': 862,
#  'Gene::6709': 863,
#  'Gene::22889': 864,
#  'Gene::558': 865,
#  'Anatomy::UBERON:0000007': 866,
#  'Gene::219938': 867,
#  'Gene::7020': 868,
#  'Gene::124583': 869,
#  'Gene::55902': 870,
#  'Biological Process::GO:0006084': 871,
#  'Gene::143684': 872,
#  'Gene::386676': 873,
#  'Gene::4208': 874,
#  'Biological Process::GO:0007268': 875,
#  'Gene::51596': 876,
#  'Gene::7080': 877,
#  'Biological Process::GO:0097485': 878,
#  'Gene::10888': 879,
#  'Gene::57761': 880,
#  'Compound::DB00586': 881,
#  'Side Effect::C0018799': 882,
#  'Gene::1642': 883,
#  'Gene::9410': 884,
#  'Gene::2776': 885,
#  'Gene::3358': 886,
#  'Anatomy::UBERON:0001007': 887,
#  'Gene::3486': 888,
#  'Gene::9120': 889,
#  'Gene::56924': 890,
#  'Gene::28969': 891,
#  'Compound::DB01567': 892,
#  'Compound::DB01588': 893,
#  'Gene::53336': 894,
#  'Gene::8646': 895,
#  'Biological Process::GO:0072091': 896,
#  'Compound::DB06701': 897,
#  'Side Effect::C0013404': 898,
#  'Gene::56655': 899,
#  'Molecular Function::GO:0016772': 900,
#  'Gene::6188': 901,
#  'Pathway::WP477_r67139': 902,
#  'Gene::84687': 903,
#  'Gene::9700': 904,
#  'Gene::4218': 905,
#  'Biological Process::GO:0044770': 906,
#  'Gene::79413': 907,
#  'Gene::5464': 908,
#  'Gene::637': 909,
#  'Gene::5290': 910,
#  'Gene::147686': 911,
#  'Gene::5111': 912,
#  'Gene::2555': 913,
#  'Biological Process::GO:0009163': 914,
#  'Gene::285268': 915,
#  'Gene::55755': 916,
#  'Gene::7976': 917,
#  'Biological Process::GO:0045786': 918,
#  'Gene::4552': 919,
#  'Gene::27023': 920,
#  'Gene::51619': 921,
#  'Gene::84937': 922,
#  'Gene::728741': 923,
#  'Gene::404093': 924,
#  'Gene::387': 925,
#  'Biological Process::GO:0032386': 926,
#  'Side Effect::C0026946': 927,
#  'Disease::DOID:1826': 928,
#  'Gene::161357': 929,
#  'Gene::197342': 930,
#  'Gene::5297': 931,
#  'Gene::6547': 932,
#  'Cellular Component::GO:0048471': 933,
#  'Gene::10616': 934,
#  'Gene::23609': 935,
#  'Gene::64770': 936,
#  'Biological Process::GO:0044380': 937,
#  'Gene::5373': 938,
#  'Gene::9935': 939,
#  'Gene::6774': 940,
#  'Biological Process::GO:2000377': 941,
#  'Gene::9793': 942,
#  'Biological Process::GO:0000226': 943,
#  'Anatomy::UBERON:0001890': 944,
#  'Gene::4359': 945,
#  'Compound::DB01248': 946,
#  'Side Effect::C0518015': 947,
#  'Gene::11282': 948,
#  'Gene::79070': 949,
#  'Gene::4741': 950,
#  'Compound::DB00811': 951,
#  'Side Effect::C3665347': 952,
#  'Gene::10277': 953,
#  'Gene::3933': 954,
#  'Gene::7314': 955,
#  'Biological Process::GO:0051646': 956,
#  'Gene::5468': 957,
#  'Gene::55107': 958,
#  'Gene::9643': 959,
#  'Gene::1066': 960,
#  'Gene::728': 961,
#  'Biological Process::GO:0050795': 962,
#  'Gene::6504': 963,
#  'Cellular Component::GO:0009897': 964,
#  'Anatomy::UBERON:0002028': 965,
#  'Gene::26232': 966,
#  'Gene::7097': 967,
#  'Gene::7994': 968,
#  'Gene::5873': 969,
#  'Biological Process::GO:0002252': 970,
#  'Gene::4776': 971,
#  'Biological Process::GO:0048646': 972,
#  'Biological Process::GO:0006935': 973,
#  'Gene::10179': 974,
#  'Gene::58': 975,
#  'Gene::2059': 976,
#  'Gene::3984': 977,
#  'Gene::16': 978,
#  'Gene::419': 979,
#  'Gene::7596': 980,
#  'Gene::57829': 981,
#  'Biological Process::GO:0002684': 982,
#  'Gene::10367': 983,
#  'Biological Process::GO:0030162': 984,
#  'Gene::117143': 985,
#  'Pathway::PC7_2570': 986,
#  'Gene::814': 987,
#  'Gene::89941': 988,
#  'Gene::10129': 989,
#  'Gene::1939': 990,
#  'Anatomy::UBERON:0002298': 991,
#  'Biological Process::GO:0051591': 992,
#  'Gene::8226': 993,
#  'Gene::9093': 994,
#  'Gene::57665': 995,
#  'Compound::DB00520': 996,
#  'Gene::10599': 997,
#  'Gene::3767': 998,
#  'Gene::7678': 999,
#  ...}

# %%
sim_matrix = np.zeros((entity_emb.shape[0],entity_emb.shape[0]))

# %%
# import collections
entity_emb.shape
sim_matrix = np.zeros((entity_emb.shape[0],entity_emb.shape[0]),dtype=float)

for i,emb1 in enumerate(entity_emb):
    for j,emb2 in enumerate(entity_emb):
        cos_sim = np.dot(emb1, emb2)/(np.linalg.norm(emb1)*np.linalg.norm(emb2))
        sim_matrix[i][j] = cos_sim
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-6bf4d3033d0c> in <module>
#       5 for i,emb1 in enumerate(entity_emb):
#       6     for j,emb2 in enumerate(entity_emb):
# ----> 7         cos_sim = np.dot(emb1, emb2)/(np.linalg.norm(emb1)*np.linalg.norm(emb2))
#       8         sim_matrix[i][j] = cos_sim
#
# KeyboardInterrupt:

# %%
# from numpy import dot
# from numpy.linalg import norm

def kg_most_similar(entity_name, topn=20):
#     entity_emb = entity_emb[entity_map[entity_name]]
    similarity = sim_matrix[entity_map[entity_name]]
    mostsimilar_idx = similarity.argsort()[-topn:][::-1]  
    mostsimilar_entities = []
    mostsimilar_entities = [entity_id_map[idx] for idx in mostsimilar_idx]
    return mostsimilar_entities

# %%
kg_most_similar('Gene::1136', topn=20)
# Out:
# 0

# %%
def check_drug_sim(x):
    drug= x.DB_ID
    disease = x.DO_ID
    #print (drug, disease)
    # search all indications treating the same disease
    # if the drug that is similar to the one in the known indication,
    # return 'INDICATION' 
    for (dr, ds) in indications_het:
        if ds == disease and dr in word_vectors:
            similarDrugs = word_vectors.most_similar(dr,topn=20)
            for en,sim in similarDrugs:
                if en == drug:
                    return INDICATION
    return ABSTAIN 

@labeling_function()
def check_disease_sim(x):
    drug= x.DB_ID
    disease = x.DO_ID
    #print (drug, disease)
    for (dr, ds) in indications_het:
        if dr == drug and ds in word_vectors:
            similarDiseases = word_vectors.most_similar(ds,topn=20)
            for en,sim in similarDiseases:
                if en == disease:
                    return INDICATION
    return ABSTAIN

# %%
@labeling_function()
def check_drug_sim(x):
    drug= x.DB_ID
    disease = x.DO_ID
    #print (drug, disease)
    # search all indications treating the same disease
    # if the drug that is similar to the one in the known indication,
    # return 'INDICATION' 
    for (dr, ds) in indications_het:
        if ds == disease and dr in word_vectors:
            similarDrugs = word_vectors.most_similar(dr,topn=20)
            for en,sim in similarDrugs:
                if en == drug:
                    return INDICATION
    return ABSTAIN 

@labeling_function()
def check_disease_sim(x):
    drug= x.DB_ID
    disease = x.DO_ID
    #print (drug, disease)
    for (dr, ds) in indications_het:
        if dr == drug and ds in word_vectors:
            similarDiseases = word_vectors.most_similar(ds,topn=20)
            for en,sim in similarDiseases:
                if en == disease:
                    return INDICATION
    return ABSTAIN

# %%
from snorkel.labeling import PandasLFApplier

lfs = [check_rule0, check_rule1, check_rule2, check_rule3, check_drug_sim, check_disease_sim]

applier = PandasLFApplier(lfs=lfs)
L_train = applier.apply(df=unlabeled_df.sample(100))
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 100/100 [00:14<00:00,  6.95it/s]

# %%
coverage_check_rule0, coverage_check_rule1, coverage_check_rule2,coverage_check_rule3, coverage_check_drug_sim, coverage_check_disease_sim = (L_train != ABSTAIN).mean(axis=0)
print(f"check_out coverage: {coverage_check_rule0 * 100:.1f}%")
print(f"check coverage: {coverage_check_rule1 * 100:.1f}%")
print(f"check_out coverage: {coverage_check_rule2 * 100:.1f}%")
print(f"check coverage: {coverage_check_rule3 * 100:.1f}%")
print(f"check coverage: {coverage_check_drug_sim * 100:.1f}%")
print(f"check coverage: {coverage_check_disease_sim * 100:.1f}%")
# Out:
# check_out coverage: 1.0%
# check coverage: 0.0%
# check_out coverage: 0.0%
# check coverage: 0.0%
# check coverage: 6.0%
# check coverage: 4.0%
