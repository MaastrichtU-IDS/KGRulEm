# %%
import pandas as pd


DISPLAY_ALL_TEXT = False

pd.set_option("display.max_colwidth", 0 if DISPLAY_ALL_TEXT else 50)

# %%
# !pip install rdflib
# Out:
# Requirement already satisfied: rdflib in /opt/conda/lib/python3.7/site-packages (5.0.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from rdflib) (1.14.0)
# Requirement already satisfied: isodate in /opt/conda/lib/python3.7/site-packages (from rdflib) (0.6.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.7/site-packages (from rdflib) (2.4.7)
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from rdflib import Namespace
from rdflib import Graph, URIRef, Literal, RDF, ConjunctiveGraph

# %% [markdown]
# ### Dataset contains text and disease and drug mentions which were extracted from the DailyMed drug lables

# %%
unlabeled_df  = pd.read_csv('../data/input/raw_cleaned.csv.zip',  compression='zip')
unlabeled_df = unlabeled_df[['DB_ID', 'DO_ID','disease', 'Label_ID', 'DrugName', 'Context','Section' ]]
len(unlabeled_df)
# Out:
# 54040

# %%
unlabeled_df.head()
# Out:
#      DB_ID         DO_ID        disease  \
# 0  DB00752  DOID_0050773  paraganglioma
# 1  DB00752      DOID_225       syndrome
# 2  DB00752     DOID_4481      hay fever
# 3  DB00752  DOID_0050773  paraganglioma
# 4  DB00752      DOID_225       syndrome
#
#                                    Label_ID         DrugName  \
# 0  9f3ad5aa-8e9d-4512-88a5-15cfd50293f9.xml  TRANYLCYPROMINE
# 1  9f3ad5aa-8e9d-4512-88a5-15cfd50293f9.xml  TRANYLCYPROMINE
# 2  9f3ad5aa-8e9d-4512-88a5-15cfd50293f9.xml  TRANYLCYPROMINE
# 3  4de045ff-f76c-48dd-9e5f-4a4f859eec8f.xml  TRANYLCYPROMINE
# 4  4de045ff-f76c-48dd-9e5f-4a4f859eec8f.xml  TRANYLCYPROMINE
#
#                                              Context           Section
# 0  concomitant use or use in rapid succession wit...  Contraindication
# 1  concomitant use or use in rapid succession wit...  Contraindication
# 2  concomitant use or use in rapid succession wit...  Contraindication
# 3  concomitant use or use in rapid succession wit...  Contraindication
# 4  concomitant use or use in rapid succession wit...  Contraindication

# %%
unlabeled_df= unlabeled_df.rename(columns={'DrugName':'Drug_name'})
unlabeled_df.drop_duplicates(subset=['Context','DO_ID'], keep='first', inplace=True)
len(unlabeled_df)
# Out:
# 39810

# %%
unlabeled_df.columns
# Out:
# Index(['DB_ID', 'DO_ID', 'disease', 'Label_ID', 'Drug_name', 'Context',
#        'Section'],
#       dtype='object')

# %%
unlabeled_df.DB_ID= 'http://bio2rdf.org/drugbank:'+unlabeled_df.DB_ID

# %%
unlabeled_df.DO_ID= 'http://bio2rdf.org/doid:'+unlabeled_df.DO_ID.str[5:]

# %% [markdown]
# ### Dataset labelled by experts to be used as test data

# %%
experts = pd.read_csv('../data/input/expert_resolved_all.csv')
experts.sample()
# Out:
#         #                                            context  \
# 257  53.0  ['\n ', 'History of cardiovascular disease (e....
#
#                 disease_name    drug_name   workers_answers   medical_expert1  \
# 257  CORONARY ARTERY DISEASE  PHENTERMINE  Contraindication  Contraindication
#
#       medical_expert2 medical_expert3      do_id            drug_brand_name  \
# 257  Contraindication          Effect  DOID_3393  Phentermine Hydrochloride
#
#      drug_id                                           label_id   sheet  \
# 257  DB00191  ../DailyMedExtracter/prescription/temp_xml/7d6...  effect
#
#      expert_consensus  inter_agree_experts   medical_expert4  \
# 257  Contraindication                    2  Contraindication
#
#     Final \n(closest option)
# 257                      NaN

# %%
experts = experts.rename(columns={'drug_name':'Drug_name',
                        'disease_name':'disease', 'context':'Context',
                        'do_id':'DO_ID','drug_id':'DB_ID',
                        'label_id':'Label_ID', 'expert_consensus':'relation'})
#experts[['DB_ID', 'DO_ID','disease', 'Label_ID', 'Set_ID','relation', 'Drug_name', 'Context','Section']]

# %% [markdown]
# ### Defininig a rule as a SPARQL query
#
# If drug ?a treats disease ?f and disease ?f and ?b, then drug ?a can treat disease ?b.
# ```
# Rule : ?a CtD ?f ^ ?f DrD ?b => ?a CtD ?b
# ```
#
# ```
# SELECT DISTINCT ?a ?b where
# {
#     ?a <http://bio2rdf.org/hetionet:CtD> ?f .
#     ?f <http://bio2rdf.org/hetionet:DrD> ?b .
#     MINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .
# }
#
# ```

# %%
query='SELECT DISTINCT ?a ?b where { ?a <http://bio2rdf.org/hetionet:CtD> ?f .'
' \n ?f <http://bio2rdf.org/hetionet:DrD> ?b . '
'\nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'
# Out:
# '\nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'

# %%
query='SELECT DISTINCT ?a ?b where { ?a <http://bio2rdf.org/hetionet:CtD> ?f . \n ?f <http://bio2rdf.org/hetionet:DrD> ?b . \n    }'

# %%
g= Graph()

# %%
# !gunzip ../data/rdf/hetionet.ttl.gz
# Out:
# gzip: ../data/rdf/hetionet.ttl already exists; do you wish to overwrite (y or n)? ^C

# %%
## We used Hetionet KG: https://het.io/about/ 
g.parse('../data/rdf/hetionet.ttl',format="ttl")
# Out:
# <Graph identifier=N20c1327c2664497aa9bc7f6e74ea8885 (<class 'rdflib.graph.Graph'>)>

# %%
query='SELECT DISTINCT ?a ?b where { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b   }'

# %%
qres= g.query(query)

# %%
indications_het =set()
for row in qres:
    #print (row['a'], row['b'])
    indications_het.add((str(row['a']),str(row['b'])))
    #break
len(indications_het)
# Out:
# 755

# %%
('http://bio2rdf.org/drugbank:DB00858', 'http://bio2rdf.org/doid:1612') in indications_het
# Out:
# False

# %% [markdown]
# ### Define KG Rules as Labeling Functions in Snorkel
# Snorkel is data labeling framework where multiple heuristic and programatic rules can be combined to assign a label to training data

# %%
# Labels to be assigned 
ABSTAIN = -1
INDICATION = 1

# %%
#!pip install snorkel

# %%
from snorkel.labeling import labeling_function


@labeling_function()
def check_rule(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            print (row['a'], row['b'])
            return INDICATION
    else:
        return ABSTAIN

# %% [markdown]
# ### Define heuristics as Labeling Functions in Snorkel
# One common approach to define a rule to label text data is use of phrase, we define a list of phrases to look for in the text

# %%
treatment_phrases= [" indicated for the treatment of",
" indicated in the management of",
" indicated for the management of",
"for the management of",
"management of",
" indicated for the maintenance of remission", 
"or the treatment of",
"in the treatment of",
" indicated as",
" indicated in",
"be effective",
"active treatment of",
" indicated for",
"treatment of",
" indicated as an adjunct",
" indicated for use in the treatment of", 
" indicated for the intermittent treatment", 
" indicated to reduce the rate of",
" indicated for the rapid control",
" indicated for the control",
"reduce the risk of",
" indicated as adjunctive treatment",
"for the treatment of"]

# %%
@labeling_function()
def check_phrase(x):
    if str(x.Context) !='nan':
        text = x.Context.lower()
        #print ('text')
        for phr in treatment_phrases:
            if phr in text:
                return INDICATION
    return ABSTAIN

# %%
from snorkel.labeling import PandasLFApplier

lfs = [check_rule, check_phrase]

applier = PandasLFApplier(lfs=lfs)
L_train = applier.apply(df=unlabeled_df.sample(100))
# Out:
#  54%|█████▍    | 54/100 [00:00<00:00, 180.42it/s]
# http://bio2rdf.org/drugbank:DB00627 http://bio2rdf.org/doid:3393
# http://bio2rdf.org/drugbank:DB00563 http://bio2rdf.org/doid:7148
# http://bio2rdf.org/drugbank:DB00860 http://bio2rdf.org/doid:2841
# 100%|██████████| 100/100 [00:00<00:00, 178.24it/s]
# http://bio2rdf.org/drugbank:DB00959 http://bio2rdf.org/doid:13189
# http://bio2rdf.org/drugbank:DB00959 http://bio2rdf.org/doid:2377
# http://bio2rdf.org/drugbank:DB00264 http://bio2rdf.org/doid:10763
# http://bio2rdf.org/drugbank:DB00273 http://bio2rdf.org/doid:6364
# http://bio2rdf.org/drugbank:DB00959 http://bio2rdf.org/doid:2841

# %%
coverage_check_out, coverage_check = (L_train != ABSTAIN).mean(axis=0)
print(f"check_out coverage: {coverage_check_out * 100:.1f}%")
print(f"check coverage: {coverage_check * 100:.1f}%")
# Out:
# check_out coverage: 8.0%
# check coverage: 77.0%

# %% [markdown]
# ### Defining labeling function for each rule

# %%
# This table is the output of the rule mining tool AIME+ using Hetnet KG
df_rules = pd.read_csv('../data/input/rules-hetionet-edges-20-04-2020.tsv',sep='\t')
df_rules.head()
# Out:
#                                         Rule  Head Coverage  Std Confidence  \
# 0  ?a  CpD  ?f  ?f  DrD  ?b   => ?a  CpD  ?b       0.235897        0.105747
# 1  ?f  CpD  ?b  ?a  CrC  ?f   => ?a  CpD  ?b       0.338462        0.080097
# 2  ?e  CpD  ?b  ?e  CrC  ?a   => ?a  CpD  ?b       0.317949        0.067982
# 3  ?a  DrD  ?f  ?b  DrD  ?f   => ?a  DrD  ?b       0.644567        0.150215
# 4  ?f  DrD  ?b  ?a  DrD  ?f   => ?a  DrD  ?b       0.631676        0.286789
#
#    PCA Confidence  Positive Examples  Body size  PCA Body size  \
# 0        0.105747                 92        870            870
# 1        0.279070                132       1648            473
# 2        0.227106                124       1824            546
# 3        0.150215                350       2330           2330
# 4        0.286789                343       1196           1196
#
#   Functional variable  Std. Lower Bound  PCA Lower Bound  PCA Conf estimation
# 0                  ?a               0.0              0.0                  0.0
# 1                  ?a               0.0              0.0                  0.0
# 2                  ?a               0.0              0.0                  0.0
# 3                  ?a               0.0              0.0                  0.0
# 4                  ?a               0.0              0.0                  0.0

# %% [markdown]
# ### Extract the rules that are related to Compound and Disease (CtD relation)

# %%
rules = []
for rule in df_rules.Rule:
    #print(rule)
    body,head = rule.split(' =>')
    
    #print(head)
    relation = head.split('  ')[1].replace('>','')
    if relation == 'CtD':
        body = body.replace('CtD','<http://bio2rdf.org/hetionet:CtD>').\
        replace('CrC','<http://bio2rdf.org/hetionet:CrC>').\
        replace('DrD','<http://bio2rdf.org/hetionet:DrD>')
        
        head = head.replace('CtD','<http://bio2rdf.org/hetionet:CtD>').\
        replace('CrC','<http://bio2rdf.org/hetionet:CrC>').\
        replace('DrD','<http://bio2rdf.org/hetionet:DrD>')
        print (relation)
        print(body, head)
        rules.append({'head':head, 'body':body, 'relation':'CtD'})
# Out:
# CtD
# ?a  <http://bio2rdf.org/hetionet:CtD>  ?f  ?f  <http://bio2rdf.org/hetionet:DrD>  ?b    ?a  <http://bio2rdf.org/hetionet:CtD>  ?b
# CtD
# ?a  <http://bio2rdf.org/hetionet:CtD>  ?f  ?b  <http://bio2rdf.org/hetionet:DrD>  ?f    ?a  <http://bio2rdf.org/hetionet:CtD>  ?b
# CtD
# ?a  <http://bio2rdf.org/hetionet:CrC>  ?f  ?f  <http://bio2rdf.org/hetionet:CtD>  ?b    ?a  <http://bio2rdf.org/hetionet:CtD>  ?b
# CtD
# ?e  <http://bio2rdf.org/hetionet:CrC>  ?a  ?e  <http://bio2rdf.org/hetionet:CtD>  ?b    ?a  <http://bio2rdf.org/hetionet:CtD>  ?b

# %%
rules
# Out:
# [{'head': ' ?a  <http://bio2rdf.org/hetionet:CtD>  ?b',
#   'body': '?a  <http://bio2rdf.org/hetionet:CtD>  ?f  ?f  <http://bio2rdf.org/hetionet:DrD>  ?b  ',
#   'relation': 'CtD'},
#  {'head': ' ?a  <http://bio2rdf.org/hetionet:CtD>  ?b',
#   'body': '?a  <http://bio2rdf.org/hetionet:CtD>  ?f  ?b  <http://bio2rdf.org/hetionet:DrD>  ?f  ',
#   'relation': 'CtD'},
#  {'head': ' ?a  <http://bio2rdf.org/hetionet:CtD>  ?b',
#   'body': '?a  <http://bio2rdf.org/hetionet:CrC>  ?f  ?f  <http://bio2rdf.org/hetionet:CtD>  ?b  ',
#   'relation': 'CtD'},
#  {'head': ' ?a  <http://bio2rdf.org/hetionet:CtD>  ?b',
#   'body': '?e  <http://bio2rdf.org/hetionet:CrC>  ?a  ?e  <http://bio2rdf.org/hetionet:CtD>  ?b  ',
#   'relation': 'CtD'}]

# %%
! pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.0.1-cp37-cp37m-manylinux1_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 14.4 MB/s eta 0:00:01
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.0.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 12.4 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.18.1 in /workspace/anaconda3/envs/bio/lib/python3.7/site-packages (from gensim) (1.6.2)
# Requirement already satisfied: numpy>=1.11.3 in /workspace/anaconda3/envs/bio/lib/python3.7/site-packages (from gensim) (1.20.2)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/workspace/anaconda3/envs/bio/lib/python3.7/site-packages/numpy-1.20.2.dist-info/METADATA'

# %% [markdown]
# ### Embedding

# %%
from gensim.models import KeyedVectors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-4c4bdb280b22> in <module>
# ----> 1 from gensim.models import KeyedVectors
#
# ModuleNotFoundError: No module named 'gensim'

# %%
word_vectors = KeyedVectors.load('../embeddings/hetionet/w2v_vectors.kv')

# %% [markdown]
# ### Convert the rules to SPARQL queries

# %%
def construct_query_for_rule(rule):
    patterns = rule['body'].split('  ')
    n_pattern = len(patterns)
    triple_pattern = """SELECT DISTINCT ?a ?b where { 
      
    """
    k =3
    for i in range(int(n_pattern/k)):
        triple_pattern += patterns[i*k] + ' '+patterns[k*i+1] + ' '+patterns[k*i+2] +' . \n'
        #print (triple_pattern)

    triple_pattern+= "MINUS {"+rule['head']+" .}"
    triple_pattern+= """
    }"""
    
    return triple_pattern

# %%
sparql0 = construct_query_for_rule(rules[0])
sparql0
qres0 = g.query(sparql0)

# %%
sparql1 = construct_query_for_rule(rules[1])
qres1 = g.query(sparql1)
sparql1
# Out:
# 'SELECT DISTINCT ?a ?b where { \n      \n    ?a <http://bio2rdf.org/hetionet:CtD> ?f . \n?b <http://bio2rdf.org/hetionet:DrD> ?f . \nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'

# %%
sparql2 = construct_query_for_rule(rules[2])
qres2 = g.query(sparql2)
sparql2
# Out:
# 'SELECT DISTINCT ?a ?b where { \n      \n    ?a <http://bio2rdf.org/hetionet:CrC> ?f . \n?f <http://bio2rdf.org/hetionet:CtD> ?b . \nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'

# %%
sparql3 = construct_query_for_rule(rules[3])
qres3 = g.query(sparql3)
sparql3
# Out:
# 'SELECT DISTINCT ?a ?b where { \n      \n    ?e <http://bio2rdf.org/hetionet:CrC> ?a . \n?e <http://bio2rdf.org/hetionet:CtD> ?b . \nMINUS { ?a  <http://bio2rdf.org/hetionet:CtD>  ?b .}\n    }'

# %% [markdown]
# ### Use the SPARQL query results in the labeling fuctions
# If the SPARQL results defined for a rule contain a drug and disease pair, it means this rule supports the fact that the drug treats the target

# %%
@labeling_function()
def check_rule0(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres0:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            return INDICATION
    return ABSTAIN


@labeling_function()
def check_rule1(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres1:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            return INDICATION
    return ABSTAIN

@labeling_function()
def check_rule2(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres2:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            return INDICATION
    return ABSTAIN

@labeling_function()
def check_rule3(x):
    drug= x.DB_ID
    disease = x.DO_ID
    for row in qres2:
        #print (row['a'], row['b'], drug, disease)
        if str(row['a']) == drug and str(row['b']) == disease:
            return INDICATION
    return ABSTAIN


@labeling_function()
def check_phrase(x):
    if str(x.Context) !='nan':
        text = x.Context.lower()
        #print ('text')
        for phr in treatment_phrases:
            if phr in text:
                return INDICATION
    return ABSTAIN

# %%
# Use Embedding model in the labeling function  
! pip install csv
# Out:
# ERROR: Could not find a version that satisfies the requirement csv
# ERROR: No matching distribution found for csv

# %%
import numpy as np
import csv

entity_emb = np.load('../data/embeddings/hetionet_TransE_l2_entity.npy')
relation_emb = np.load('../data/embeddings/hetionet_TransE_l2_relation.npy')

entity_idmap_file = '../data/embeddings/entities.tsv'
relation_idmap_file = '../data/embeddings/relations.tsv'

entity_map = {}
entity_id_map = {}
relation_map = {}
with open(entity_idmap_file, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t', fieldnames=['id','name'])
    for row_val in reader:
        entity_map[row_val['name']] = int(row_val['id'])
        entity_id_map[int(row_val['id'])] = row_val['name']
        
with open(relation_idmap_file, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t', fieldnames=['id','name'])
    for row_val in reader:
        relation_map[row_val['name']] = int(row_val['id'])    
entity_map
# Out:
# {'Gene::1136': 0,
#  'Biological Process::GO:0034622': 1,
#  'Gene::79017': 2,
#  'Gene::7296': 3,
#  'Gene::124274': 4,
#  'Molecular Function::GO:0001653': 5,
#  'Gene::23588': 6,
#  'Gene::7043': 7,
#  'Disease::DOID:1826': 8,
#  'Gene::6529': 9,
#  'Anatomy::UBERON:0001911': 10,
#  'Gene::51172': 11,
#  'Gene::3708': 12,
#  'Biological Process::GO:0044344': 13,
#  'Gene::6934': 14,
#  'Biological Process::GO:0048640': 15,
#  'Anatomy::UBERON:0002369': 16,
#  'Gene::11138': 17,
#  'Gene::25942': 18,
#  'Gene::10417': 19,
#  'Gene::9123': 20,
#  'Molecular Function::GO:0022857': 21,
#  'Gene::171392': 22,
#  'Molecular Function::GO:0000977': 23,
#  'Gene::5365': 24,
#  'Biological Process::GO:0007411': 25,
#  'Anatomy::UBERON:0002030': 26,
#  'Gene::283450': 27,
#  'Gene::64841': 28,
#  'Cellular Component::GO:0005768': 29,
#  'Gene::5521': 30,
#  'Cellular Component::GO:0000159': 31,
#  'Anatomy::UBERON:0000007': 32,
#  'Gene::25844': 33,
#  'Anatomy::UBERON:0001295': 34,
#  'Gene::51128': 35,
#  'Gene::26130': 36,
#  'Molecular Function::GO:0032794': 37,
#  'Gene::5073': 38,
#  'Gene::1808': 39,
#  'Gene::125061': 40,
#  'Biological Process::GO:1901606': 41,
#  'Gene::9759': 42,
#  'Molecular Function::GO:0000988': 43,
#  'Compound::DB01056': 44,
#  'Gene::1544': 45,
#  'Gene::9420': 46,
#  'Biological Process::GO:0016125': 47,
#  'Anatomy::UBERON:0000178': 48,
#  'Gene::6498': 49,
#  'Gene::57505': 50,
#  'Biological Process::GO:0006412': 51,
#  'Anatomy::UBERON:0002046': 52,
#  'Gene::64417': 53,
#  'Gene::8930': 54,
#  'Molecular Function::GO:0016798': 55,
#  'Gene::4646': 56,
#  'Cellular Component::GO:0005635': 57,
#  'Gene::8607': 58,
#  'Gene::226': 59,
#  'Gene::84168': 60,
#  'Cellular Component::GO:0030027': 61,
#  'Gene::285349': 62,
#  'Gene::4123': 63,
#  'Anatomy::UBERON:0002048': 64,
#  'Gene::81688': 65,
#  'Anatomy::UBERON:0001896': 66,
#  'Gene::51057': 67,
#  'Anatomy::UBERON:0002081': 68,
#  'Gene::51334': 69,
#  'Anatomy::UBERON:0000057': 70,
#  'Gene::162427': 71,
#  'Gene::84971': 72,
#  'Biological Process::GO:0042157': 73,
#  'Anatomy::UBERON:0000996': 74,
#  'Gene::51194': 75,
#  'Compound::DB00198': 76,
#  'Side Effect::C0011253': 77,
#  'Gene::9836': 78,
#  'Biological Process::GO:0034470': 79,
#  'Gene::3631': 80,
#  'Molecular Function::GO:0016316': 81,
#  'Gene::7335': 82,
#  'Pathway::PC7_8288': 83,
#  'Compound::DB00745': 84,
#  'Side Effect::C0014518': 85,
#  'Gene::5714': 86,
#  'Pathway::PC7_7483': 87,
#  'Anatomy::UBERON:0001637': 88,
#  'Gene::55276': 89,
#  'Gene::2194': 90,
#  'Biological Process::GO:0071345': 91,
#  'Gene::23287': 92,
#  'Biological Process::GO:0001654': 93,
#  'Gene::22905': 94,
#  'Cellular Component::GO:0045334': 95,
#  'Gene::2067': 96,
#  'Gene::29082': 97,
#  'Anatomy::UBERON:0001225': 98,
#  'Gene::8764': 99,
#  'Anatomy::UBERON:0000029': 100,
#  'Gene::81502': 101,
#  'Anatomy::UBERON:0001235': 102,
#  'Gene::1979': 103,
#  'Gene::29763': 104,
#  'Anatomy::UBERON:0002113': 105,
#  'Gene::51780': 106,
#  'Anatomy::UBERON:0001044': 107,
#  'Gene::84305': 108,
#  'Anatomy::UBERON:0000473': 109,
#  'Gene::79609': 110,
#  'Anatomy::UBERON:0000992': 111,
#  'Gene::121274': 112,
#  'Anatomy::UBERON:0000948': 113,
#  'Gene::64921': 114,
#  'Anatomy::UBERON:0000997': 115,
#  'Gene::9892': 116,
#  'Gene::4435': 117,
#  'Molecular Function::GO:0001067': 118,
#  'Gene::8027': 119,
#  'Gene::6829': 120,
#  'Pathway::PC7_8317': 121,
#  'Gene::10765': 122,
#  'Biological Process::GO:0016570': 123,
#  'Gene::5564': 124,
#  'Gene::5687': 125,
#  'Gene::2969': 126,
#  'Gene::10569': 127,
#  'Anatomy::UBERON:0000991': 128,
#  'Gene::51312': 129,
#  'Gene::8848': 130,
#  'Gene::3945': 131,
#  'Gene::7633': 132,
#  'Pathway::PC7_4116': 133,
#  'Gene::9045': 134,
#  'Pathway::PC7_4085': 135,
#  'Gene::1044': 136,
#  'Gene::9690': 137,
#  'Gene::5894': 138,
#  'Pathway::PC7_4741': 139,
#  'Gene::3769': 140,
#  'Gene::118987': 141,
#  'Anatomy::UBERON:0001891': 142,
#  'Gene::65078': 143,
#  'Gene::64210': 144,
#  'Gene::670': 145,
#  'Gene::402': 146,
#  'Gene::262': 147,
#  'Gene::26205': 148,
#  'Gene::8480': 149,
#  'Biological Process::GO:0044764': 150,
#  'Gene::54361': 151,
#  'Biological Process::GO:0010893': 152,
#  'Gene::390259': 153,
#  'Gene::8216': 154,
#  'Gene::10874': 155,
#  'Biological Process::GO:0006937': 156,
#  'Gene::6880': 157,
#  'Biological Process::GO:0006354': 158,
#  'Gene::57156': 159,
#  'Anatomy::UBERON:0000955': 160,
#  'Gene::79683': 161,
#  'Gene::54947': 162,
#  'Compound::DB01204': 163,
#  'Gene::259266': 164,
#  'Anatomy::UBERON:0001017': 165,
#  'Gene::9903': 166,
#  'Gene::29086': 167,
#  'Biological Process::GO:0006303': 168,
#  'Gene::3071': 169,
#  'Biological Process::GO:0032715': 170,
#  'Gene::79577': 171,
#  'Pathway::PC7_7784': 172,
#  'Gene::9258': 173,
#  'Anatomy::UBERON:0002185': 174,
#  'Gene::563': 175,
#  'Gene::78996': 176,
#  'Gene::5693': 177,
#  'Gene::2745': 178,
#  'Gene::9060': 179,
#  'Anatomy::UBERON:0002371': 180,
#  'Gene::8740': 181,
#  'Gene::5717': 182,
#  'Gene::10868': 183,
#  'Gene::5579': 184,
#  'Biological Process::GO:0002684': 185,
#  'Compound::DB00538': 186,
#  'Side Effect::C2830004': 187,
#  'Gene::56704': 188,
#  'Biological Process::GO:0007204': 189,
#  'Anatomy::UBERON:0001016': 190,
#  'Gene::57602': 191,
#  'Compound::DB00749': 192,
#  'Side Effect::C0948594': 193,
#  'Gene::7349': 194,
#  'Biological Process::GO:1903524': 195,
#  'Gene::51478': 196,
#  'Gene::6839': 197,
#  'Gene::1741': 198,
#  'Biological Process::GO:0008285': 199,
#  'Gene::1152': 200,
#  'Gene::5594': 201,
#  'Biological Process::GO:0060416': 202,
#  'Compound::DB01080': 203,
#  'Side Effect::C0858635': 204,
#  'Gene::80224': 205,
#  'Molecular Function::GO:0051540': 206,
#  'Gene::164633': 207,
#  'Gene::116729': 208,
#  'Gene::3791': 209,
#  'Gene::29924': 210,
#  'Gene::1643': 211,
#  'Gene::53343': 212,
#  'Gene::26271': 213,
#  'Gene::23338': 214,
#  'Gene::10007': 215,
#  'Gene::440503': 216,
#  'Biological Process::GO:0051345': 217,
#  'Gene::5027': 218,
#  'Biological Process::GO:0098542': 219,
#  'Gene::51548': 220,
#  'Molecular Function::GO:0003714': 221,
#  'Anatomy::UBERON:0001890': 222,
#  'Gene::80309': 223,
#  'Gene::5782': 224,
#  'Gene::5274': 225,
#  'Anatomy::UBERON:0001296': 226,
#  'Gene::56903': 227,
#  'Gene::8451': 228,
#  'Biological Process::GO:0070911': 229,
#  'Gene::835': 230,
#  'Biological Process::GO:0007169': 231,
#  'Gene::6612': 232,
#  'Gene::9020': 233,
#  'Gene::2542': 234,
#  'Gene::29098': 235,
#  'Molecular Function::GO:0005085': 236,
#  'Compound::DB00576': 237,
#  'Compound::DB00664': 238,
#  'Gene::5547': 239,
#  'Gene::10038': 240,
#  'Gene::5711': 241,
#  'Biological Process::GO:0002429': 242,
#  'Gene::147463': 243,
#  'Gene::9472': 244,
#  'Biological Process::GO:1901021': 245,
#  'Gene::26353': 246,
#  'Gene::57192': 247,
#  'Gene::54811': 248,
#  'Gene::58478': 249,
#  'Gene::22928': 250,
#  'Compound::DB00014': 251,
#  'Side Effect::C0041582': 252,
#  'Gene::55300': 253,
#  'Gene::2523': 254,
#  'Gene::701': 255,
#  'Biological Process::GO:0051302': 256,
#  'Anatomy::UBERON:0001013': 257,
#  'Gene::158584': 258,
#  'Anatomy::UBERON:0000043': 259,
#  'Gene::2289': 260,
#  'Gene::23354': 261,
#  'Biological Process::GO:1903047': 262,
#  'Gene::3600': 263,
#  'Biological Process::GO:0007267': 264,
#  'Gene::80139': 265,
#  'Biological Process::GO:0040017': 266,
#  'Gene::23513': 267,
#  'Biological Process::GO:0006897': 268,
#  'Gene::5473': 269,
#  'Biological Process::GO:0008645': 270,
#  'Anatomy::UBERON:0004535': 271,
#  'Gene::29119': 272,
#  'Anatomy::UBERON:0001231': 273,
#  'Gene::79971': 274,
#  'Anatomy::UBERON:0002107': 275,
#  'Gene::8287': 276,
#  'Gene::91662': 277,
#  'Biological Process::GO:0042345': 278,
#  'Gene::55755': 279,
#  'Gene::79745': 280,
#  'Anatomy::UBERON:0000970': 281,
#  'Gene::55164': 282,
#  'Gene::51764': 283,
#  'Biological Process::GO:0007606': 284,
#  'Gene::3458': 285,
#  'Gene::2195': 286,
#  'Gene::4000': 287,
#  'Biological Process::GO:0036498': 288,
#  'Gene::5927': 289,
#  'Gene::84617': 290,
#  'Gene::10574': 291,
#  'Gene::353322': 292,
#  'Compound::DB01576': 293,
#  'Side Effect::C0220870': 294,
#  'Gene::64840': 295,
#  'Disease::DOID:1612': 296,
#  'Gene::7057': 297,
#  'Gene::316': 298,
#  'Gene::7514': 299,
#  'Biological Process::GO:0010608': 300,
#  'Gene::10811': 301,
#  'Gene::154865': 302,
#  'Gene::7407': 303,
#  'Biological Process::GO:0006438': 304,
#  'Gene::8648': 305,
#  'Gene::27173': 306,
#  'Biological Process::GO:0048705': 307,
#  'Gene::119692': 308,
#  'Gene::4673': 309,
#  'Gene::6678': 310,
#  'Biological Process::GO:0030324': 311,
#  'Gene::3059': 312,
#  'Pathway::WP23_r79985': 313,
#  'Gene::221301': 314,
#  'Gene::5797': 315,
#  'Biological Process::GO:0048646': 316,
#  'Gene::1440': 317,
#  'Pathway::WP530_r79331': 318,
#  'Anatomy::UBERON:0002082': 319,
#  'Gene::55726': 320,
#  'Gene::51005': 321,
#  'Gene::57804': 322,
#  'Gene::728441': 323,
#  'Biological Process::GO:0006691': 324,
#  'Gene::1021': 325,
#  'Gene::11004': 326,
#  'Compound::DB00570': 327,
#  'Gene::2314': 328,
#  'Gene::991': 329,
#  'Gene::1396': 330,
#  'Gene::6618': 331,
#  'Gene::7316': 332,
#  'Gene::51184': 333,
#  'Compound::DB00996': 334,
#  'Side Effect::C0021177': 335,
#  'Gene::84694': 336,
#  'Molecular Function::GO:0022829': 337,
#  'Gene::5695': 338,
#  'Gene::5702': 339,
#  'Gene::2633': 340,
#  'Gene::10694': 341,
#  'Gene::58526': 342,
#  'Compound::DB00472': 343,
#  'Side Effect::C0002878': 344,
#  'Pathway::PC7_4107': 345,
#  'Gene::4170': 346,
#  'Gene::5366': 347,
#  'Gene::10444': 348,
#  'Biological Process::GO:0070647': 349,
#  'Anatomy::UBERON:0000006': 350,
#  'Gene::6132': 351,
#  'Gene::3646': 352,
#  'Gene::4637': 353,
#  'Gene::6045': 354,
#  'Gene::51619': 355,
#  'Gene::113251': 356,
#  'Gene::572': 357,
#  'Biological Process::GO:0007005': 358,
#  'Anatomy::UBERON:0002037': 359,
#  'Gene::4135': 360,
#  'Gene::51365': 361,
#  'Biological Process::GO:0044712': 362,
#  'Gene::93233': 363,
#  'Biological Process::GO:0048858': 364,
#  'Gene::23135': 365,
#  'Anatomy::UBERON:0001895': 366,
#  'Gene::3625': 367,
#  'Gene::7298': 368,
#  'Cellular Component::GO:0005759': 369,
#  'Gene::10211': 370,
#  'Gene::64127': 371,
#  'Biological Process::GO:0032733': 372,
#  'Gene::3146': 373,
#  'Gene::3636': 374,
#  'Pathway::PC7_4688': 375,
#  'Gene::6050': 376,
#  'Gene::29968': 377,
#  'Gene::3598': 378,
#  'Gene::23512': 379,
#  'Compound::DB00877': 380,
#  'Gene::55178': 381,
#  'Compound::DB01268': 382,
#  'Side Effect::C0014591': 383,
#  'Gene::57447': 384,
#  'Biological Process::GO:0010574': 385,
#  'Gene::25788': 386,
#  'Molecular Function::GO:0017111': 387,
#  'Gene::10699': 388,
#  'Gene::5788': 389,
#  'Cellular Component::GO:0005912': 390,
#  'Gene::50808': 391,
#  'Gene::30836': 392,
#  'Gene::28985': 393,
#  'Biological Process::GO:0043604': 394,
#  'Gene::23030': 395,
#  'Gene::6192': 396,
#  'Pathway::PC7_5973': 397,
#  'Gene::10454': 398,
#  'Biological Process::GO:0060840': 399,
#  'Gene::56262': 400,
#  'Biological Process::GO:0098656': 401,
#  'Gene::57491': 402,
#  'Gene::9275': 403,
#  'Gene::4830': 404,
#  'Biological Process::GO:0009260': 405,
#  'Gene::1075': 406,
#  'Molecular Function::GO:0031404': 407,
#  'Disease::DOID:7148': 408,
#  'Gene::3106': 409,
#  'Gene::84766': 410,
#  'Biological Process::GO:0032411': 411,
#  'Gene::939': 412,
#  'Biological Process::GO:0070229': 413,
#  'Gene::1431': 414,
#  'Gene::84444': 415,
#  'Gene::2033': 416,
#  'Gene::10980': 417,
#  'Gene::79089': 418,
#  'Anatomy::UBERON:0002097': 419,
#  'Gene::2051': 420,
#  'Gene::93109': 421,
#  'Gene::11336': 422,
#  'Gene::22796': 423,
#  'Gene::10767': 424,
#  'Gene::8692': 425,
#  'Gene::2203': 426,
#  'Gene::54963': 427,
#  'Gene::5441': 428,
#  'Biological Process::GO:0009452': 429,
#  'Anatomy::UBERON:0000966': 430,
#  'Gene::8120': 431,
#  'Gene::25937': 432,
#  'Biological Process::GO:1903533': 433,
#  'Anatomy::UBERON:0003126': 434,
#  'Gene::29116': 435,
#  'Gene::27072': 436,
#  'Biological Process::GO:0016050': 437,
#  'Gene::2869': 438,
#  'Gene::126282': 439,
#  'Gene::59341': 440,
#  'Biological Process::GO:0046879': 441,
#  'Gene::673': 442,
#  'Compound::DB00537': 443,
#  'Side Effect::C0424000': 444,
#  'Gene::6262': 445,
#  'Compound::DB00303': 446,
#  'Side Effect::C0022346': 447,
#  'Compound::DB00740': 448,
#  'Side Effect::C0033774': 449,
#  'Gene::79738': 450,
#  'Gene::259217': 451,
#  'Anatomy::UBERON:0002368': 452,
#  'Gene::84706': 453,
#  'Gene::896': 454,
#  'Cellular Component::GO:1990234': 455,
#  'Gene::8545': 456,
#  'Molecular Function::GO:1990837': 457,
#  'Gene::6507': 458,
#  'Cellular Component::GO:0043197': 459,
#  'Gene::624': 460,
#  'Gene::10580': 461,
#  'Molecular Function::GO:0032403': 462,
#  'Gene::65980': 463,
#  'Gene::2248': 464,
#  'Gene::4488': 465,
#  'Gene::10059': 466,
#  'Gene::9016': 467,
#  'Gene::54915': 468,
#  'Gene::7392': 469,
#  'Gene::10978': 470,
#  'Biological Process::GO:0006954': 471,
#  'Gene::8724': 472,
#  'Gene::7343': 473,
#  'Molecular Function::GO:0044212': 474,
#  'Gene::5597': 475,
#  'Gene::10015': 476,
#  'Gene::4552': 477,
#  'Biological Process::GO:0072521': 478,
#  'Gene::9197': 479,
#  'Gene::5046': 480,
#  'Biological Process::GO:0070848': 481,
#  'Gene::355': 482,
#  'Gene::8795': 483,
#  'Gene::3628': 484,
#  'Gene::30001': 485,
#  'Gene::5885': 486,
#  'Gene::57678': 487,
#  'Gene::55553': 488,
#  'Biological Process::GO:0043009': 489,
#  'Biological Process::GO:0051251': 490,
#  'Gene::2907': 491,
#  'Gene::6710': 492,
#  'Gene::5690': 493,
#  'Biological Process::GO:0043488': 494,
#  'Anatomy::UBERON:0002240': 495,
#  'Gene::10241': 496,
#  'Gene::132158': 497,
#  'Gene::8527': 498,
#  'Gene::4090': 499,
#  'Gene::5936': 500,
#  'Gene::286380': 501,
#  'Gene::1066': 502,
#  'Gene::55116': 503,
#  'Gene::203523': 504,
#  'Gene::54556': 505,
#  'Gene::2852': 506,
#  'Gene::9831': 507,
#  'Gene::6182': 508,
#  'Gene::2557': 509,
#  'Gene::2562': 510,
#  'Anatomy::UBERON:0001675': 511,
#  'Gene::57211': 512,
#  'Gene::51629': 513,
#  'Cellular Component::GO:0019866': 514,
#  'Gene::8626': 515,
#  'Biological Process::GO:0045747': 516,
#  'Anatomy::UBERON:0001132': 517,
#  'Gene::3181': 518,
#  'Gene::2965': 519,
#  'Pathway::PC7_6795': 520,
#  'Gene::7046': 521,
#  'Gene::55032': 522,
#  'Gene::23308': 523,
#  'Biological Process::GO:0050671': 524,
#  'Gene::56122': 525,
#  'Biological Process::GO:0007156': 526,
#  'Gene::83593': 527,
#  'Gene::6622': 528,
#  'Biological Process::GO:0051952': 529,
#  'Gene::79796': 530,
#  'Gene::26287': 531,
#  'Biological Process::GO:0051093': 532,
#  'Anatomy::UBERON:0002673': 533,
#  'Gene::100423062': 534,
#  'Gene::10252': 535,
#  'Gene::10273': 536,
#  'Gene::23332': 537,
#  'Biological Process::GO:0090162': 538,
#  'Gene::115286': 539,
#  'Biological Process::GO:0046942': 540,
#  'Gene::266727': 541,
#  'Gene::6161': 542,
#  'Gene::1447': 543,
#  'Gene::4802': 544,
#  'Gene::7226': 545,
#  'Gene::6434': 546,
#  'Gene::7532': 547,
#  'Anatomy::UBERON:0001893': 548,
#  'Gene::51227': 549,
#  'Compound::DB04844': 550,
#  'Gene::79600': 551,
#  'Gene::149041': 552,
#  'Biological Process::GO:0034110': 553,
#  'Gene::7342': 554,
#  'Biological Process::GO:0072359': 555,
#  'Gene::7358': 556,
#  'Gene::2769': 557,
#  'Gene::23077': 558,
#  'Gene::64969': 559,
#  'Cellular Component::GO:0005763': 560,
#  'Compound::DB00987': 561,
#  'Gene::1301': 562,
#  'Gene::80329': 563,
#  'Biological Process::GO:0002252': 564,
#  'Gene::5914': 565,
#  'Gene::1368': 566,
#  'Gene::5566': 567,
#  'Gene::10057': 568,
#  'Gene::79603': 569,
#  'Gene::11044': 570,
#  'Gene::4093': 571,
#  'Gene::7554': 572,
#  'Gene::4329': 573,
#  'Gene::51070': 574,
#  'Gene::10404': 575,
#  'Gene::54902': 576,
#  'Gene::550': 577,
#  'Gene::126070': 578,
#  'Gene::386676': 579,
#  'Gene::5604': 580,
#  'Gene::4097': 581,
#  'Gene::3801': 582,
#  'Gene::54814': 583,
#  'Gene::200081': 584,
#  'Gene::9217': 585,
#  'Biological Process::GO:0048524': 586,
#  'Gene::665': 587,
#  'Gene::7184': 588,
#  'Biological Process::GO:0043066': 589,
#  'Gene::4709': 590,
#  'Biological Process::GO:0009116': 591,
#  'Gene::2219': 592,
#  'Pathway::PC7_3903': 593,
#  'Gene::166614': 594,
#  'Biological Process::GO:0021860': 595,
#  'Gene::51228': 596,
#  'Gene::3957': 597,
#  'Molecular Function::GO:0030246': 598,
#  'Gene::6565': 599,
#  'Disease::DOID:10283': 600,
#  'Gene::3169': 601,
#  'Gene::51347': 602,
#  'Gene::27338': 603,
#  'Gene::4943': 604,
#  'Gene::7538': 605,
#  'Gene::898': 606,
#  'Pathway::WP2359_r72121': 607,
#  'Gene::1499': 608,
#  'Biological Process::GO:0032210': 609,
#  'Anatomy::UBERON:0001831': 610,
#  'Gene::7311': 611,
#  'Gene::7415': 612,
#  'Gene::55786': 613,
#  'Gene::10939': 614,
#  'Gene::128866': 615,
#  'Anatomy::UBERON:0001135': 616,
#  'Gene::9601': 617,
#  'Gene::55917': 618,
#  'Biological Process::GO:0034762': 619,
#  'Gene::11005': 620,
#  'Biological Process::GO:0022404': 621,
#  'Gene::4593': 622,
#  'Gene::79080': 623,
#  'Gene::2146': 624,
#  'Gene::1802': 625,
#  'Gene::5691': 626,
#  'Biological Process::GO:1901652': 627,
#  'Gene::342908': 628,
#  'Gene::3456': 629,
#  'Biological Process::GO:0001959': 630,
#  'Gene::51086': 631,
#  'Gene::353500': 632,
#  'Molecular Function::GO:0005160': 633,
#  'Gene::1020': 634,
#  'Gene::23327': 635,
#  'Gene::4734': 636,
#  'Gene::6774': 637,
#  'Gene::55699': 638,
#  'Disease::DOID:90': 639,
#  'Anatomy::UBERON:0001130': 640,
#  'Gene::84193': 641,
#  'Gene::4651': 642,
#  'Gene::4350': 643,
#  'Gene::222865': 644,
#  'Gene::51655': 645,
#  'Gene::5373': 646,
#  'Biological Process::GO:0038094': 647,
#  'Gene::57578': 648,
#  'Gene::2115': 649,
#  'Gene::10051': 650,
#  'Compound::DB00978': 651,
#  'Side Effect::C0010520': 652,
#  'Gene::56852': 653,
#  'Cellular Component::GO:0042405': 654,
#  'Gene::4860': 655,
#  'Molecular Function::GO:0008144': 656,
#  'Gene::151742': 657,
#  'Gene::9267': 658,
#  'Anatomy::UBERON:0002367': 659,
#  'Gene::5091': 660,
#  'Gene::10620': 661,
#  'Gene::23383': 662,
#  'Gene::5753': 663,
#  'Gene::10125': 664,
#  'Gene::6633': 665,
#  'Gene::192670': 666,
#  'Gene::4222': 667,
#  'Gene::100529261': 668,
#  'Gene::6470': 669,
#  'Gene::9627': 670,
#  'Gene::6549': 671,
#  'Biological Process::GO:0006885': 672,
#  'Gene::5359': 673,
#  'Biological Process::GO:0010912': 674,
#  'Gene::5224': 675,
#  'Gene::10140': 676,
#  'Disease::DOID:986': 677,
#  'Gene::51111': 678,
#  'Anatomy::UBERON:0000474': 679,
#  'Gene::79778': 680,
#  'Gene::27071': 681,
#  'Gene::3183': 682,
#  'Gene::3609': 683,
#  'Gene::9637': 684,
#  'Biological Process::GO:0044087': 685,
#  'Pathway::PC7_5330': 686,
#  'Compound::DB00180': 687,
#  'Gene::54511': 688,
#  'Cellular Component::GO:0048471': 689,
#  'Gene::64919': 690,
#  'Gene::2710': 691,
#  'Biological Process::GO:0019432': 692,
#  'Gene::8659': 693,
#  'Gene::25966': 694,
#  'Gene::7314': 695,
#  'Biological Process::GO:0006281': 696,
#  'Gene::10262': 697,
#  'Gene::801': 698,
#  'Molecular Function::GO:0035254': 699,
#  'Gene::83548': 700,
#  'Gene::9132': 701,
#  'Molecular Function::GO:0015077': 702,
#  'Gene::119749': 703,
#  'Biological Process::GO:0007600': 704,
#  'Gene::23048': 705,
#  'Gene::754': 706,
#  'Biological Process::GO:2001020': 707,
#  'Gene::8153': 708,
#  'Gene::27183': 709,
#  'Gene::4824': 710,
#  'Gene::5763': 711,
#  'Gene::7013': 712,
#  'Gene::10320': 713,
#  'Gene::392': 714,
#  'Gene::51234': 715,
#  'Gene::2960': 716,
#  'Gene::89870': 717,
#  'Gene::1588': 718,
#  'Biological Process::GO:0002676': 719,
#  'Gene::129401': 720,
#  'Gene::8625': 721,
#  'Gene::23029': 722,
#  'Gene::22871': 723,
#  'Biological Process::GO:0023041': 724,
#  'Gene::8644': 725,
#  'Gene::6119': 726,
#  'Gene::2778': 727,
#  'Gene::4173': 728,
#  'Disease::DOID:1793': 729,
#  'Gene::7032': 730,
#  'Gene::2987': 731,
#  'Molecular Function::GO:0016776': 732,
#  'Gene::3087': 733,
#  'Biological Process::GO:0010563': 734,
#  'Anatomy::UBERON:0002073': 735,
#  'Gene::2547': 736,
#  'Gene::682': 737,
#  'Compound::DB08912': 738,
#  'Side Effect::C0242528': 739,
#  'Compound::DB00397': 740,
#  'Side Effect::C0013384': 741,
#  'Gene::90865': 742,
#  'Gene::121551': 743,
#  'Gene::39': 744,
#  'Gene::3898': 745,
#  'Gene::79145': 746,
#  'Cellular Component::GO:0005740': 747,
#  'Gene::91574': 748,
#  'Gene::5689': 749,
#  'Biological Process::GO:0051439': 750,
#  'Biological Process::GO:0097305': 751,
#  'Gene::51062': 752,
#  'Gene::64425': 753,
#  'Gene::220064': 754,
#  'Gene::1745': 755,
#  'Gene::342184': 756,
#  'Biological Process::GO:0072078': 757,
#  'Gene::57097': 758,
#  'Gene::2936': 759,
#  'Biological Process::GO:0006352': 760,
#  'Gene::114609': 761,
#  'Gene::8574': 762,
#  'Gene::3281': 763,
#  'Gene::5819': 764,
#  'Biological Process::GO:0002714': 765,
#  'Gene::51250': 766,
#  'Gene::6389': 767,
#  'Gene::6195': 768,
#  'Gene::9043': 769,
#  'Biological Process::GO:0010720': 770,
#  'Compound::DB00687': 771,
#  'Side Effect::C0002792': 772,
#  'Gene::84290': 773,
#  'Gene::3978': 774,
#  'Gene::9961': 775,
#  'Gene::369': 776,
#  'Biological Process::GO:0033138': 777,
#  'Gene::56984': 778,
#  'Gene::5329': 779,
#  'Biological Process::GO:0030162': 780,
#  'Gene::23258': 781,
#  'Gene::148156': 782,
#  'Gene::51542': 783,
#  'Gene::113130': 784,
#  'Cellular Component::GO:0005694': 785,
#  'Gene::6198': 786,
#  'Gene::134553': 787,
#  'Anatomy::UBERON:0000002': 788,
#  'Gene::28232': 789,
#  'Gene::153020': 790,
#  'Biological Process::GO:0007264': 791,
#  'Gene::5685': 792,
#  'Gene::5334': 793,
#  'Gene::342125': 794,
#  'Gene::7975': 795,
#  'Gene::26354': 796,
#  'Gene::334': 797,
#  'Gene::5621': 798,
#  'Gene::55578': 799,
#  'Biological Process::GO:0009790': 800,
#  'Gene::64766': 801,
#  'Gene::9091': 802,
#  'Gene::116987': 803,
#  'Compound::DB00607': 804,
#  'Side Effect::C0003862': 805,
#  'Anatomy::UBERON:0000010': 806,
#  'Gene::51747': 807,
#  'Gene::5523': 808,
#  'Gene::22921': 809,
#  'Gene::182': 810,
#  'Gene::6509': 811,
#  'Gene::154091': 812,
#  'Gene::55852': 813,
#  'Pathway::PC7_5530': 814,
#  'Gene::1649': 815,
#  'Gene::6670': 816,
#  'Gene::55070': 817,
#  'Gene::3358': 818,
#  'Biological Process::GO:0045834': 819,
#  'Gene::128553': 820,
#  'Gene::84131': 821,
#  'Compound::DB01092': 822,
#  'Gene::5187': 823,
#  'Gene::136259': 824,
#  'Gene::8869': 825,
#  'Disease::DOID:9970': 826,
#  'Gene::1278': 827,
#  'Gene::5423': 828,
#  'Gene::4323': 829,
#  'Gene::10362': 830,
#  'Compound::DB00860': 831,
#  'Side Effect::C0027813': 832,
#  'Gene::10114': 833,
#  'Gene::3853': 834,
#  'Gene::8454': 835,
#  'Gene::602': 836,
#  'Biological Process::GO:0002268': 837,
#  'Disease::DOID:14227': 838,
#  'Gene::10524': 839,
#  'Gene::4750': 840,
#  'Gene::6647': 841,
#  'Biological Process::GO:0080135': 842,
#  'Gene::164127': 843,
#  'Gene::8674': 844,
#  'Gene::10228': 845,
#  'Gene::83637': 846,
#  'Gene::3276': 847,
#  'Gene::6348': 848,
#  'Gene::5284': 849,
#  'Biological Process::GO:0002251': 850,
#  'Gene::57519': 851,
#  'Gene::1359': 852,
#  'Biological Process::GO:0051707': 853,
#  'Gene::9641': 854,
#  'Gene::25840': 855,
#  'Gene::1573': 856,
#  'Gene::114883': 857,
#  'Gene::26047': 858,
#  'Cellular Component::GO:0031252': 859,
#  'Gene::191': 860,
#  'Gene::645': 861,
#  'Gene::4057': 862,
#  'Biological Process::GO:0001817': 863,
#  'Gene::11325': 864,
#  'Gene::23118': 865,
#  'Biological Process::GO:0032200': 866,
#  'Gene::5525': 867,
#  'Cellular Component::GO:0031672': 868,
#  'Gene::51092': 869,
#  'Molecular Function::GO:0022884': 870,
#  'Gene::54586': 871,
#  'Cellular Component::GO:0005769': 872,
#  'Gene::84295': 873,
#  'Gene::6415': 874,
#  'Gene::51230': 875,
#  'Gene::56919': 876,
#  'Molecular Function::GO:0003690': 877,
#  'Compound::DB00655': 878,
#  'Compound::DB02187': 879,
#  'Gene::23503': 880,
#  'Compound::DB01171': 881,
#  'Compound::DB00679': 882,
#  'Side Effect::C0014457': 883,
#  'Gene::25945': 884,
#  'Gene::23774': 885,
#  'Gene::31': 886,
#  'Gene::26520': 887,
#  'Anatomy::UBERON:0000995': 888,
#  'Gene::6422': 889,
#  'Gene::8611': 890,
#  'Gene::9847': 891,
#  'Gene::715': 892,
#  'Biological Process::GO:0002455': 893,
#  'Gene::8403': 894,
#  'Gene::58490': 895,
#  'Gene::10409': 896,
#  'Biological Process::GO:0045927': 897,
#  'Compound::DB00482': 898,
#  'Side Effect::C0005779': 899,
#  'Gene::7018': 900,
#  'Gene::167681': 901,
#  'Gene::79958': 902,
#  'Gene::142683': 903,
#  'Gene::391': 904,
#  'Cellular Component::GO:0042175': 905,
#  'Gene::27297': 906,
#  'Biological Process::GO:0009607': 907,
#  'Gene::1435': 908,
#  'Biological Process::GO:0002158': 909,
#  'Gene::7128': 910,
#  'Gene::80312': 911,
#  'Biological Process::GO:0070988': 912,
#  'Gene::9362': 913,
#  'Biological Process::GO:0022603': 914,
#  'Gene::136242': 915,
#  'Biological Process::GO:0051674': 916,
#  'Gene::3157': 917,
#  'Pathway::WP474_r80208': 918,
#  'Gene::3608': 919,
#  'Gene::6160': 920,
#  'Compound::DB00275': 921,
#  'Side Effect::C0023380': 922,
#  'Gene::1005': 923,
#  'Gene::1010': 924,
#  'Pharmacologic Class::N0000000236': 925,
#  'Compound::DB00262': 926,
#  'Gene::351': 927,
#  'Gene::4939': 928,
#  'Gene::1488': 929,
#  'Pathway::WP2064_r79263': 930,
#  'Gene::57673': 931,
#  'Molecular Function::GO:0000182': 932,
#  'Gene::286053': 933,
#  'Biological Process::GO:0016925': 934,
#  'Gene::4760': 935,
#  'Molecular Function::GO:0001104': 936,
#  'Gene::10055': 937,
#  'Biological Process::GO:0045064': 938,
#  'Gene::8934': 939,
#  'Biological Process::GO:0051223': 940,
#  'Compound::DB01586': 941,
#  'Side Effect::C0026113': 942,
#  'Anatomy::UBERON:0002349': 943,
#  'Gene::51616': 944,
#  'Gene::2669': 945,
#  'Gene::23281': 946,
#  'Gene::6155': 947,
#  'Gene::27043': 948,
#  'Gene::10881': 949,
#  'Gene::8347': 950,
#  'Gene::59353': 951,
#  'Gene::51127': 952,
#  'Gene::55680': 953,
#  'Gene::26580': 954,
#  'Gene::3251': 955,
#  'Biological Process::GO:0009125': 956,
#  'Anatomy::UBERON:0000922': 957,
#  'Gene::117854': 958,
#  'Gene::51750': 959,
#  'Biological Process::GO:0031297': 960,
#  'Gene::57407': 961,
#  'Gene::8569': 962,
#  'Gene::5771': 963,
#  'Biological Process::GO:0010883': 964,
#  'Anatomy::UBERON:0001004': 965,
#  'Gene::80020': 966,
#  'Gene::84058': 967,
#  'Gene::9463': 968,
#  'Biological Process::GO:0032956': 969,
#  'Side Effect::C0151744': 970,
#  'Molecular Function::GO:0005506': 971,
#  'Gene::3198': 972,
#  'Gene::9755': 973,
#  'Gene::653656': 974,
#  'Biological Process::GO:0006325': 975,
#  'Gene::7388': 976,
#  'Gene::143502': 977,
#  'Molecular Function::GO:0004930': 978,
#  'Gene::112399': 979,
#  'Biological Process::GO:0031638': 980,
#  'Gene::3569': 981,
#  'Gene::477': 982,
#  'Biological Process::GO:1903170': 983,
#  'Gene::1815': 984,
#  'Biological Process::GO:0007187': 985,
#  'Gene::9124': 986,
#  'Disease::DOID:10652': 987,
#  'Gene::79658': 988,
#  'Gene::4513': 989,
#  'Gene::7189': 990,
#  'Gene::23066': 991,
#  'Gene::55055': 992,
#  'Pathway::PC7_5527': 993,
#  'Gene::10551': 994,
#  'Gene::10605': 995,
#  'Biological Process::GO:0043489': 996,
#  'Gene::8312': 997,
#  'Biological Process::GO:0030178': 998,
#  'Compound::DB00869': 999,
#  ...}

# %%
sim_matrix = np.zeros((entity_emb.shape[0],entity_emb.shape[0]))
sim_matrix[10][10]
# Out:
# 0.0

# %%
# import collections
entity_emb.shape

sim_matrix = np.zeros((entity_emb.shape[0],entity_emb.shape[0]),dtype=float)

for i,emb1 in enumerate(entity_emb):
    for j,emb2 in enumerate(entity_emb):
        cos_sim = np.dot(emb1, emb2)/(np.linalg.norm(emb1)*np.linalg.norm(emb2))
        print(i,j,cos_sim)
        sim_matrix[i][j] = cos_sim
# Out:
# 102

# %%
# from numpy import dot
# from numpy.linalg import norm

def kg_most_similar(entity_name, topn=20):
#     entity_emb = entity_emb[entity_map[entity_name]]
    similarity = sim_matrix[entity_map[entity_name]]
    mostsimilar_idx = similarity.argsort()[-topn:][::-1]  
    mostsimilar_entities = []
    mostsimilar_entities = [entity_id_map[idx] for idx in mostsimilar_idx]
    return mostsimilar_entities

# %%
kg_most_similar('Gene::1136', topn=20)
# Out:
# 0

# %%
def check_drug_sim(x):
    drug= x.DB_ID
    disease = x.DO_ID
    #print (drug, disease)
    # search all indications treating the same disease
    # if the drug that is similar to the one in the known indication,
    # return 'INDICATION' 
    for (dr, ds) in indications_het:
        if ds == disease and dr in word_vectors:
            similarDrugs = word_vectors.most_similar(dr,topn=20)
            for en,sim in similarDrugs:
                if en == drug:
                    return INDICATION
    return ABSTAIN 

@labeling_function()
def check_disease_sim(x):
    drug= x.DB_ID
    disease = x.DO_ID
    #print (drug, disease)
    for (dr, ds) in indications_het:
        if dr == drug and ds in word_vectors:
            similarDiseases = word_vectors.most_similar(ds,topn=20)
            for en,sim in similarDiseases:
                if en == disease:
                    return INDICATION
    return ABSTAIN

# %%
@labeling_function()
def check_drug_sim(x):
    drug= x.DB_ID
    disease = x.DO_ID
    #print (drug, disease)
    # search all indications treating the same disease
    # if the drug that is similar to the one in the known indication,
    # return 'INDICATION' 
    for (dr, ds) in indications_het:
        if ds == disease and dr in word_vectors:
            similarDrugs = word_vectors.most_similar(dr,topn=20)
            for en,sim in similarDrugs:
                if en == drug:
                    return INDICATION
    return ABSTAIN 

@labeling_function()
def check_disease_sim(x):
    drug= x.DB_ID
    disease = x.DO_ID
    #print (drug, disease)
    for (dr, ds) in indications_het:
        if dr == drug and ds in word_vectors:
            similarDiseases = word_vectors.most_similar(ds,topn=20)
            for en,sim in similarDiseases:
                if en == disease:
                    return INDICATION
    return ABSTAIN

# %%
from snorkel.labeling import PandasLFApplier

lfs = [check_rule0, check_rule1, check_rule2, check_rule3, check_drug_sim, check_disease_sim]

applier = PandasLFApplier(lfs=lfs)
L_train = applier.apply(df=unlabeled_df.sample(100))
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 100/100 [00:14<00:00,  6.95it/s]

# %%
coverage_check_rule0, coverage_check_rule1, coverage_check_rule2,coverage_check_rule3, coverage_check_drug_sim, coverage_check_disease_sim = (L_train != ABSTAIN).mean(axis=0)
print(f"check_out coverage: {coverage_check_rule0 * 100:.1f}%")
print(f"check coverage: {coverage_check_rule1 * 100:.1f}%")
print(f"check_out coverage: {coverage_check_rule2 * 100:.1f}%")
print(f"check coverage: {coverage_check_rule3 * 100:.1f}%")
print(f"check coverage: {coverage_check_drug_sim * 100:.1f}%")
print(f"check coverage: {coverage_check_disease_sim * 100:.1f}%")
# Out:
# check_out coverage: 1.0%
# check coverage: 0.0%
# check_out coverage: 0.0%
# check coverage: 0.0%
# check coverage: 6.0%
# check coverage: 4.0%
